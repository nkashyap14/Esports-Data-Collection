# %%
from csgo.parser import DemoParser
import numpy
import csv
import pandas
import pyserialem
import os
from tabulate import tabulate

# %%
def getDemoPaths(dir_path):
    demoPaths = []
    x = 0
    for filename in os.listdir(dir_path):
        demoPaths.append(os.path.join(dir_path, filename))
    return demoPaths

# %%
def generateDemoParsers(paths):
    demo_parsers = []
    for x in paths:
        demoParser = DemoParser(demofile=x, demo_id = x.split('/')[-1].split('.')[0].split('_')[0], parse_rate=128)
        demo_parsers.append(demoParser)
    print("# Demo Parsers: " + str(len(demo_parsers)))
    return demo_parsers

# %%
def generateData(parsers):
    killData, roundData, damageData = [], [], [],
    for x in parsers:
        x.parse()
        killData.append(x._parse_kills(return_type="df"))
        roundData.append(x._parse_rounds(return_type="df"))
        damageData.append(x._parse_damages(return_type="df"))
    return (killData, roundData, damageData)

# %%
def concat_data(aggregate_data):
    final_df = None
    for x in aggregate_data:
        final_df = pandas.concat([final_df, x], ignore_index=True)
    return final_df

# %%
def createSidedCSVDF(players, damageData, killData, roundData):
    locationNames = []
    playerNames = []

    Kills = []
    Deaths = []
    KdDifferential = []
    DamageDealt = []
    DamageTaken = []
    DamageDifferential = []
    sides = []
    totalRounds = []
    dataframe = {}
    for x in players.keys():
        for y in killData[killData['AttackerName'].isin(players[x]) | killData['VictimName'].isin(players[x])].VictimAreaName.value_counts().index:
            
            tempCTKills = len(killData[killData['AttackerName'].isin(players[x])][killData['AttackerAreaName'] == y][killData['AttackerSide'] == 'CT'])
            tempCTDeaths = len(killData[killData['VictimName'].isin(players[x])][killData['VictimAreaName'] == y][killData['VictimSide'] == 'CT'])
            tempCTKdDifferential = tempCTKills - tempCTDeaths
            
            tempCTDamageDealt = damageData[damageData['AttackerName'].isin(players[x])][damageData['AttackerAreaName'] == y][damageData['AttackerSide'] == 'CT'].HpDamageTaken.sum()
            tempCTDamageTaken = damageData[damageData['VictimName'].isin(players[x])][damageData['VictimAreaName'] == y][damageData['VictimSide'] == 'CT'].HpDamageTaken.sum()
            tempCTDamageDifferential = tempCTDamageDealt - tempCTDamageTaken
                                                                                                             
            tempTKills = len(killData[killData['AttackerName'].isin(players[x])][killData['AttackerAreaName'] == y][killData['AttackerSide'] == 'T'])
            tempTDeaths = len(killData[killData['VictimName'].isin(players[x])][killData['VictimAreaName'] == y][killData['VictimSide'] == 'T'])
            tempTKdDifferential = tempTKills - tempTDeaths
                                                                                                             
            tempTDamageDealt = damageData[damageData['AttackerName'].isin(players[x])][damageData['AttackerAreaName'] == y][damageData['AttackerSide'] == 'T'].HpDamageTaken.sum()
            tempTDamageTaken = damageData[damageData['VictimName'].isin(players[x])][damageData['VictimAreaName'] == y][damageData['VictimSide'] == 'T'].HpDamageTaken.sum()
            tempTDamageDifferential = tempTDamageDealt - tempTDamageTaken
            
            tempTotalRounds = 0
                                                    
            for z in killData[killData.AttackerName.isin(players[x])].MatchId.value_counts().index:
                tempTotalRounds += roundData[roundData['MatchId'] == z].iloc[-1].RoundNum
            
            locationNames.append(y)
            locationNames.append(y)
            
            playerNames.append(x)
            playerNames.append(x)
            
            Kills.append(tempCTKills)
            Kills.append(tempTKills)
            
            
            Deaths.append(tempCTDeaths)
            Deaths.append(tempTDeaths)
            
            
            KdDifferential.append(tempCTKdDifferential)
            KdDifferential.append(tempTKdDifferential)
            
            
            DamageDealt.append(tempCTDamageDealt)
            DamageTaken.append(tempCTDamageTaken)
            DamageDifferential.append(tempCTDamageDifferential)
            
            DamageDealt.append(tempTDamageDealt)
            DamageTaken.append(tempTDamageTaken)
            DamageDifferential.append(tempTDamageDifferential)
            
            sides.append('CT')
            sides.append('T')
            
            
            totalRounds.append(tempTotalRounds)
            totalRounds.append(tempTotalRounds)
    
    dataframe['Location'] = locationNames
    dataframe['Player'] = playerNames
    dataframe['Kills'] = Kills
    dataframe['Deaths'] = Deaths
    dataframe['K/D'] = KdDifferential
    dataframe['Damage Dealt'] = DamageDealt
    dataframe['Damage Taken'] = DamageTaken
    dataframe['Damage Differential'] = DamageDifferential
    dataframe['Side'] = sides
    dataframe['Total Rounds'] = totalRounds
    
    return pandas.DataFrame.from_dict(dataframe, orient='columns')

# %%
demo_path = '/mnt/d/Top_Players/ESL_Pro_League_Season_13'

# %%
output_path = './damageDifferentials/epls13/eslInfernoDifferentials.csv'

# %%
demos = getDemoPaths(demo_path)

# %%
infernoDemos = []
for x in demos:
    if "inferno" in x:
        infernoDemos.append(x)

# %%
infernoMappingPath = './mappings/mappings/de_inferno_place_mappings.txt'

# %%
file = open(infernoMappingPath, 'r')
lines = file.readlines()
file.close()

# %%
for x in range(len(lines)):
    if(lines[x][-1] == '\n'):
        lines[x] = lines[x][:-1]

# %%
mappedPlaceNames = {}
for x in lines:
    if(x != ''):
            mappedPlaceNames[x.split(':')[0]] = x.split(':')[1]

# %%
parsers = generateDemoParsers(infernoDemos)
# Out:
# 14:01:27 [INFO] Go version>=1.14.0
# 14:01:27 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/astralis-vs-endpoint-m1-inferno.dem
# 14:01:27 [INFO] Setting demo id to astralis-vs-endpoint-m1-inferno
# 14:01:27 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/astralis-vs-evil-geniuses-m3-inferno.dem
# 14:01:28 [INFO] Setting demo id to astralis-vs-evil-geniuses-m3-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/astralis-vs-virtus-pro-m1-inferno.dem
# 14:01:28 [INFO] Setting demo id to astralis-vs-virtus-pro-m1-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/complexity-vs-nip-m3-inferno.dem
# 14:01:28 [INFO] Setting demo id to complexity-vs-nip-m3-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/ence-vs-nip-m3-inferno.dem
# 14:01:28 [INFO] Setting demo id to ence-vs-nip-m3-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/endpoint-vs-fnatic-m1-inferno.dem
# 14:01:28 [INFO] Setting demo id to endpoint-vs-fnatic-m1-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/endpoint-vs-liquid-m1-inferno.dem
# 14:01:28 [INFO] Setting demo id to endpoint-vs-liquid-m1-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/evil-geniuses-vs-endpoint-m1-inferno.dem
# 14:01:28 [INFO] Setting demo id to evil-geniuses-vs-endpoint-m1-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/evil-geniuses-vs-liquid-m1-inferno.dem
# 14:01:28 [INFO] Setting demo id to evil-geniuses-vs-liquid-m1-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/faze-vs-ence-m2-inferno.dem
# 14:01:28 [INFO] Setting demo id to faze-vs-ence-m2-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/fnatic-vs-evil-geniuses-m2-inferno.dem
# 14:01:28 [INFO] Setting demo id to fnatic-vs-evil-geniuses-m2-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/furia-vs-funplus-phoenix-m3-inferno.dem
# 14:01:28 [INFO] Setting demo id to furia-vs-funplus-phoenix-m3-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/furia-vs-gambit-m2-inferno.dem
# 14:01:28 [INFO] Setting demo id to furia-vs-gambit-m2-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:28 [INFO] Go version>=1.14.0
# 14:01:28 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/g2-vs-faze-m2-inferno.dem
# 14:01:28 [INFO] Setting demo id to g2-vs-faze-m2-inferno
# 14:01:28 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/g2-vs-liquid-m3-inferno.dem
# 14:01:29 [INFO] Setting demo id to g2-vs-liquid-m3-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-astralis-m2-inferno.dem
# 14:01:29 [INFO] Setting demo id to gambit-vs-astralis-m2-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-heroic-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to gambit-vs-heroic-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-mibr-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to gambit-vs-mibr-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-nip-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to gambit-vs-nip-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/heroic-vs-nip-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to heroic-vs-nip-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/mibr-vs-furia-m2-inferno.dem
# 14:01:29 [INFO] Setting demo id to mibr-vs-furia-m2-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/mousesports-vs-faze-m2-inferno.dem
# 14:01:29 [INFO] Setting demo id to mousesports-vs-faze-m2-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/nip-vs-mousesports-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to nip-vs-mousesports-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/teamone-vs-gambit-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to teamone-vs-gambit-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-complexity-m2-inferno.dem
# 14:01:29 [INFO] Setting demo id to virtus-pro-vs-complexity-m2-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-ence-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to virtus-pro-vs-ence-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:29 [INFO] Go version>=1.14.0
# 14:01:29 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-endpoint-m1-inferno.dem
# 14:01:29 [INFO] Setting demo id to virtus-pro-vs-endpoint-m1-inferno
# 14:01:29 [INFO] Setting parse rate to 128
# 14:01:30 [INFO] Go version>=1.14.0
# 14:01:30 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-evil-geniuses-m3-inferno.dem
# 14:01:30 [INFO] Setting demo id to virtus-pro-vs-evil-geniuses-m3-inferno
# 14:01:30 [INFO] Setting parse rate to 128
# 14:01:30 [INFO] Go version>=1.14.0
# 14:01:30 [INFO] Initialized CSGODemoParser with demofile /mnt/d/Top_Players/ESL_Pro_League_Season_13/vitality-vs-nip-m1-inferno.dem
# 14:01:30 [INFO] Setting demo id to vitality-vs-nip-m1-inferno
# 14:01:30 [INFO] Setting parse rate to 128
# # Demo Parsers: 29

# %%
infernoKills, infernoROunds, infernoDamages = generateData(parsers)
# Out:
# 14:01:30 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:01:30 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/astralis-vs-endpoint-m1-inferno.dem
# 14:01:50 [INFO] Wrote demo parse output to astralis-vs-endpoint-m1-inferno.json
# 14:01:50 [INFO] Reading in JSON from astralis-vs-endpoint-m1-inferno.json
# 14:01:50 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:01:50 [INFO] Successfully parsed JSON output
# 14:01:50 [INFO] Successfully returned JSON output
# 14:01:50 [INFO] Parsed kills to Pandas DataFrame
# 14:01:50 [INFO] Parsed rounds to Pandas DataFrame
# 14:01:50 [INFO] Parsed damages to Pandas DataFrame
# 14:01:50 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:01:50 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/astralis-vs-evil-geniuses-m3-inferno.dem
# 14:02:06 [INFO] Wrote demo parse output to astralis-vs-evil-geniuses-m3-inferno.json
# 14:02:06 [INFO] Reading in JSON from astralis-vs-evil-geniuses-m3-inferno.json
# 14:02:06 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:02:06 [INFO] Successfully parsed JSON output
# 14:02:06 [INFO] Successfully returned JSON output
# 14:02:06 [INFO] Parsed kills to Pandas DataFrame
# 14:02:06 [INFO] Parsed rounds to Pandas DataFrame
# 14:02:06 [INFO] Parsed damages to Pandas DataFrame
# 14:02:06 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:02:06 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/astralis-vs-virtus-pro-m1-inferno.dem
# 14:02:27 [INFO] Wrote demo parse output to astralis-vs-virtus-pro-m1-inferno.json
# 14:02:27 [INFO] Reading in JSON from astralis-vs-virtus-pro-m1-inferno.json
# 14:02:27 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:02:27 [INFO] Successfully parsed JSON output
# 14:02:27 [INFO] Successfully returned JSON output
# 14:02:27 [INFO] Parsed kills to Pandas DataFrame
# 14:02:27 [INFO] Parsed rounds to Pandas DataFrame
# 14:02:27 [INFO] Parsed damages to Pandas DataFrame
# 14:02:27 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:02:27 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/complexity-vs-nip-m3-inferno.dem
# 14:02:41 [INFO] Wrote demo parse output to complexity-vs-nip-m3-inferno.json
# 14:02:41 [INFO] Reading in JSON from complexity-vs-nip-m3-inferno.json
# 14:02:42 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:02:42 [INFO] Successfully parsed JSON output
# 14:02:42 [INFO] Successfully returned JSON output
# 14:02:42 [INFO] Parsed kills to Pandas DataFrame
# 14:02:42 [INFO] Parsed rounds to Pandas DataFrame
# 14:02:42 [INFO] Parsed damages to Pandas DataFrame
# 14:02:42 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:02:42 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/ence-vs-nip-m3-inferno.dem
# 14:02:55 [INFO] Wrote demo parse output to ence-vs-nip-m3-inferno.json
# 14:02:55 [INFO] Reading in JSON from ence-vs-nip-m3-inferno.json
# 14:02:55 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:02:55 [INFO] Successfully parsed JSON output
# 14:02:55 [INFO] Successfully returned JSON output
# 14:02:55 [INFO] Parsed kills to Pandas DataFrame
# 14:02:55 [INFO] Parsed rounds to Pandas DataFrame
# 14:02:55 [INFO] Parsed damages to Pandas DataFrame
# 14:02:55 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:02:55 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/endpoint-vs-fnatic-m1-inferno.dem
# 14:03:11 [INFO] Wrote demo parse output to endpoint-vs-fnatic-m1-inferno.json
# 14:03:11 [INFO] Reading in JSON from endpoint-vs-fnatic-m1-inferno.json
# 14:03:12 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:03:12 [INFO] Successfully parsed JSON output
# 14:03:12 [INFO] Successfully returned JSON output
# 14:03:12 [INFO] Parsed kills to Pandas DataFrame
# 14:03:12 [INFO] Parsed rounds to Pandas DataFrame
# 14:03:12 [INFO] Parsed damages to Pandas DataFrame
# 14:03:12 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:03:12 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/endpoint-vs-liquid-m1-inferno.dem
# 14:03:31 [INFO] Wrote demo parse output to endpoint-vs-liquid-m1-inferno.json
# 14:03:31 [INFO] Reading in JSON from endpoint-vs-liquid-m1-inferno.json
# 14:03:32 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:03:32 [INFO] Successfully parsed JSON output
# 14:03:32 [INFO] Successfully returned JSON output
# 14:03:32 [INFO] Parsed kills to Pandas DataFrame
# 14:03:32 [INFO] Parsed rounds to Pandas DataFrame
# 14:03:32 [INFO] Parsed damages to Pandas DataFrame
# 14:03:32 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:03:32 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/evil-geniuses-vs-endpoint-m1-inferno.dem
# 14:03:49 [INFO] Wrote demo parse output to evil-geniuses-vs-endpoint-m1-inferno.json
# 14:03:49 [INFO] Reading in JSON from evil-geniuses-vs-endpoint-m1-inferno.json
# 14:03:50 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:03:50 [INFO] Successfully parsed JSON output
# 14:03:50 [INFO] Successfully returned JSON output
# 14:03:50 [INFO] Parsed kills to Pandas DataFrame
# 14:03:50 [INFO] Parsed rounds to Pandas DataFrame
# 14:03:50 [INFO] Parsed damages to Pandas DataFrame
# 14:03:50 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:03:50 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/evil-geniuses-vs-liquid-m1-inferno.dem
# 14:04:05 [INFO] Wrote demo parse output to evil-geniuses-vs-liquid-m1-inferno.json
# 14:04:05 [INFO] Reading in JSON from evil-geniuses-vs-liquid-m1-inferno.json
# 14:04:05 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:04:05 [INFO] Successfully parsed JSON output
# 14:04:05 [INFO] Successfully returned JSON output
# 14:04:05 [INFO] Parsed kills to Pandas DataFrame
# 14:04:05 [INFO] Parsed rounds to Pandas DataFrame
# 14:04:05 [INFO] Parsed damages to Pandas DataFrame
# 14:04:05 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:04:05 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/faze-vs-ence-m2-inferno.dem
# 14:04:16 [INFO] Wrote demo parse output to faze-vs-ence-m2-inferno.json
# 14:04:16 [INFO] Reading in JSON from faze-vs-ence-m2-inferno.json
# 14:04:16 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:04:16 [INFO] Successfully parsed JSON output
# 14:04:16 [INFO] Successfully returned JSON output
# 14:04:16 [INFO] Parsed kills to Pandas DataFrame
# 14:04:16 [INFO] Parsed rounds to Pandas DataFrame
# 14:04:16 [INFO] Parsed damages to Pandas DataFrame
# 14:04:16 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:04:16 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/fnatic-vs-evil-geniuses-m2-inferno.dem
# 14:04:29 [INFO] Wrote demo parse output to fnatic-vs-evil-geniuses-m2-inferno.json
# 14:04:29 [INFO] Reading in JSON from fnatic-vs-evil-geniuses-m2-inferno.json
# 14:04:30 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:04:30 [INFO] Successfully parsed JSON output
# 14:04:30 [INFO] Successfully returned JSON output
# 14:04:30 [INFO] Parsed kills to Pandas DataFrame
# 14:04:30 [INFO] Parsed rounds to Pandas DataFrame
# 14:04:30 [INFO] Parsed damages to Pandas DataFrame
# 14:04:30 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:04:30 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/furia-vs-funplus-phoenix-m3-inferno.dem
# 14:04:44 [INFO] Wrote demo parse output to furia-vs-funplus-phoenix-m3-inferno.json
# 14:04:44 [INFO] Reading in JSON from furia-vs-funplus-phoenix-m3-inferno.json
# 14:04:45 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:04:45 [INFO] Successfully parsed JSON output
# 14:04:45 [INFO] Successfully returned JSON output
# 14:04:45 [INFO] Parsed kills to Pandas DataFrame
# 14:04:45 [INFO] Parsed rounds to Pandas DataFrame
# 14:04:45 [INFO] Parsed damages to Pandas DataFrame
# 14:04:45 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:04:45 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/furia-vs-gambit-m2-inferno.dem
# 14:05:03 [INFO] Wrote demo parse output to furia-vs-gambit-m2-inferno.json
# 14:05:03 [INFO] Reading in JSON from furia-vs-gambit-m2-inferno.json
# 14:05:04 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:05:04 [INFO] Successfully parsed JSON output
# 14:05:04 [INFO] Successfully returned JSON output
# 14:05:04 [INFO] Parsed kills to Pandas DataFrame
# 14:05:04 [INFO] Parsed rounds to Pandas DataFrame
# 14:05:04 [INFO] Parsed damages to Pandas DataFrame
# 14:05:04 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:05:04 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/g2-vs-faze-m2-inferno.dem
# 14:05:20 [INFO] Wrote demo parse output to g2-vs-faze-m2-inferno.json
# 14:05:20 [INFO] Reading in JSON from g2-vs-faze-m2-inferno.json
# 14:05:21 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:05:21 [INFO] Successfully parsed JSON output
# 14:05:21 [INFO] Successfully returned JSON output
# 14:05:21 [INFO] Parsed kills to Pandas DataFrame
# 14:05:21 [INFO] Parsed rounds to Pandas DataFrame
# 14:05:21 [INFO] Parsed damages to Pandas DataFrame
# 14:05:21 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:05:21 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/g2-vs-liquid-m3-inferno.dem
# 14:05:38 [INFO] Wrote demo parse output to g2-vs-liquid-m3-inferno.json
# 14:05:38 [INFO] Reading in JSON from g2-vs-liquid-m3-inferno.json
# 14:05:39 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:05:39 [INFO] Successfully parsed JSON output
# 14:05:39 [INFO] Successfully returned JSON output
# 14:05:39 [INFO] Parsed kills to Pandas DataFrame
# 14:05:39 [INFO] Parsed rounds to Pandas DataFrame
# 14:05:39 [INFO] Parsed damages to Pandas DataFrame
# 14:05:39 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:05:39 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-astralis-m2-inferno.dem
# 14:05:55 [INFO] Wrote demo parse output to gambit-vs-astralis-m2-inferno.json
# 14:05:55 [INFO] Reading in JSON from gambit-vs-astralis-m2-inferno.json
# 14:05:56 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:05:56 [INFO] Successfully parsed JSON output
# 14:05:56 [INFO] Successfully returned JSON output
# 14:05:56 [INFO] Parsed kills to Pandas DataFrame
# 14:05:56 [INFO] Parsed rounds to Pandas DataFrame
# 14:05:56 [INFO] Parsed damages to Pandas DataFrame
# 14:05:56 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:05:56 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-heroic-m1-inferno.dem
# 14:06:18 [INFO] Wrote demo parse output to gambit-vs-heroic-m1-inferno.json
# 14:06:18 [INFO] Reading in JSON from gambit-vs-heroic-m1-inferno.json
# 14:06:18 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:06:18 [INFO] Successfully parsed JSON output
# 14:06:18 [INFO] Successfully returned JSON output
# 14:06:18 [INFO] Parsed kills to Pandas DataFrame
# 14:06:18 [INFO] Parsed rounds to Pandas DataFrame
# 14:06:18 [INFO] Parsed damages to Pandas DataFrame
# 14:06:18 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:06:18 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-mibr-m1-inferno.dem
# 14:06:32 [INFO] Wrote demo parse output to gambit-vs-mibr-m1-inferno.json
# 14:06:32 [INFO] Reading in JSON from gambit-vs-mibr-m1-inferno.json
# 14:06:32 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:06:32 [INFO] Successfully parsed JSON output
# 14:06:32 [INFO] Successfully returned JSON output
# 14:06:32 [INFO] Parsed kills to Pandas DataFrame
# 14:06:32 [INFO] Parsed rounds to Pandas DataFrame
# 14:06:32 [INFO] Parsed damages to Pandas DataFrame
# 14:06:32 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:06:32 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/gambit-vs-nip-m1-inferno.dem
# 14:06:46 [INFO] Wrote demo parse output to gambit-vs-nip-m1-inferno.json
# 14:06:46 [INFO] Reading in JSON from gambit-vs-nip-m1-inferno.json
# 14:06:47 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:06:47 [INFO] Successfully parsed JSON output
# 14:06:47 [INFO] Successfully returned JSON output
# 14:06:47 [INFO] Parsed kills to Pandas DataFrame
# 14:06:47 [INFO] Parsed rounds to Pandas DataFrame
# 14:06:47 [INFO] Parsed damages to Pandas DataFrame
# 14:06:47 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:06:47 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/heroic-vs-nip-m1-inferno.dem
# 14:07:05 [INFO] Wrote demo parse output to heroic-vs-nip-m1-inferno.json
# 14:07:05 [INFO] Reading in JSON from heroic-vs-nip-m1-inferno.json
# 14:07:06 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:07:06 [INFO] Successfully parsed JSON output
# 14:07:06 [INFO] Successfully returned JSON output
# 14:07:06 [INFO] Parsed kills to Pandas DataFrame
# 14:07:06 [INFO] Parsed rounds to Pandas DataFrame
# 14:07:06 [INFO] Parsed damages to Pandas DataFrame
# 14:07:06 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:07:06 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/mibr-vs-furia-m2-inferno.dem
# 14:07:20 [INFO] Wrote demo parse output to mibr-vs-furia-m2-inferno.json
# 14:07:20 [INFO] Reading in JSON from mibr-vs-furia-m2-inferno.json
# 14:07:21 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:07:21 [INFO] Successfully parsed JSON output
# 14:07:21 [INFO] Successfully returned JSON output
# 14:07:21 [INFO] Parsed kills to Pandas DataFrame
# 14:07:21 [INFO] Parsed rounds to Pandas DataFrame
# 14:07:21 [INFO] Parsed damages to Pandas DataFrame
# 14:07:21 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:07:21 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/mousesports-vs-faze-m2-inferno.dem
# 14:07:35 [INFO] Wrote demo parse output to mousesports-vs-faze-m2-inferno.json
# 14:07:35 [INFO] Reading in JSON from mousesports-vs-faze-m2-inferno.json
# 14:07:35 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:07:35 [INFO] Successfully parsed JSON output
# 14:07:35 [INFO] Successfully returned JSON output
# 14:07:35 [INFO] Parsed kills to Pandas DataFrame
# 14:07:35 [INFO] Parsed rounds to Pandas DataFrame
# 14:07:35 [INFO] Parsed damages to Pandas DataFrame
# 14:07:35 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:07:35 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/nip-vs-mousesports-m1-inferno.dem
# 14:07:50 [INFO] Wrote demo parse output to nip-vs-mousesports-m1-inferno.json
# 14:07:50 [INFO] Reading in JSON from nip-vs-mousesports-m1-inferno.json
# 14:07:50 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:07:50 [INFO] Successfully parsed JSON output
# 14:07:50 [INFO] Successfully returned JSON output
# 14:07:50 [INFO] Parsed kills to Pandas DataFrame
# 14:07:50 [INFO] Parsed rounds to Pandas DataFrame
# 14:07:50 [INFO] Parsed damages to Pandas DataFrame
# 14:07:50 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:07:50 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/teamone-vs-gambit-m1-inferno.dem
# 14:08:03 [INFO] Wrote demo parse output to teamone-vs-gambit-m1-inferno.json
# 14:08:03 [INFO] Reading in JSON from teamone-vs-gambit-m1-inferno.json
# 14:08:03 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:08:03 [INFO] Successfully parsed JSON output
# 14:08:03 [INFO] Successfully returned JSON output
# 14:08:03 [INFO] Parsed kills to Pandas DataFrame
# 14:08:03 [INFO] Parsed rounds to Pandas DataFrame
# 14:08:03 [INFO] Parsed damages to Pandas DataFrame
# 14:08:03 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:08:03 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-complexity-m2-inferno.dem
# 14:08:22 [INFO] Wrote demo parse output to virtus-pro-vs-complexity-m2-inferno.json
# 14:08:22 [INFO] Reading in JSON from virtus-pro-vs-complexity-m2-inferno.json
# 14:08:24 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:08:24 [INFO] Successfully parsed JSON output
# 14:08:24 [INFO] Successfully returned JSON output
# 14:08:24 [INFO] Parsed kills to Pandas DataFrame
# 14:08:24 [INFO] Parsed rounds to Pandas DataFrame
# 14:08:24 [INFO] Parsed damages to Pandas DataFrame
# 14:08:24 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:08:24 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-ence-m1-inferno.dem
# 14:08:38 [INFO] Wrote demo parse output to virtus-pro-vs-ence-m1-inferno.json
# 14:08:38 [INFO] Reading in JSON from virtus-pro-vs-ence-m1-inferno.json
# 14:08:39 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:08:39 [INFO] Successfully parsed JSON output
# 14:08:39 [INFO] Successfully returned JSON output
# 14:08:39 [INFO] Parsed kills to Pandas DataFrame
# 14:08:39 [INFO] Parsed rounds to Pandas DataFrame
# 14:08:39 [INFO] Parsed damages to Pandas DataFrame
# 14:08:39 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:08:39 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-endpoint-m1-inferno.dem
# 14:08:54 [INFO] Wrote demo parse output to virtus-pro-vs-endpoint-m1-inferno.json
# 14:08:54 [INFO] Reading in JSON from virtus-pro-vs-endpoint-m1-inferno.json
# 14:08:54 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:08:54 [INFO] Successfully parsed JSON output
# 14:08:54 [INFO] Successfully returned JSON output
# 14:08:54 [INFO] Parsed kills to Pandas DataFrame
# 14:08:54 [INFO] Parsed rounds to Pandas DataFrame
# 14:08:54 [INFO] Parsed damages to Pandas DataFrame
# 14:08:54 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:08:54 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/virtus-pro-vs-evil-geniuses-m3-inferno.dem
# 14:09:19 [INFO] Wrote demo parse output to virtus-pro-vs-evil-geniuses-m3-inferno.json
# 14:09:19 [INFO] Reading in JSON from virtus-pro-vs-evil-geniuses-m3-inferno.json
# 14:09:19 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:09:19 [INFO] Successfully parsed JSON output
# 14:09:19 [INFO] Successfully returned JSON output
# 14:09:19 [INFO] Parsed kills to Pandas DataFrame
# 14:09:19 [INFO] Parsed rounds to Pandas DataFrame
# 14:09:19 [INFO] Parsed damages to Pandas DataFrame
# 14:09:19 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 14:09:19 [INFO] Looking for file at /mnt/d/Top_Players/ESL_Pro_League_Season_13/vitality-vs-nip-m1-inferno.dem
# 14:09:39 [INFO] Wrote demo parse output to vitality-vs-nip-m1-inferno.json
# 14:09:39 [INFO] Reading in JSON from vitality-vs-nip-m1-inferno.json
# 14:09:40 [INFO] JSON data loaded, available in the `json` attribute to parser
# 14:09:40 [INFO] Successfully parsed JSON output
# 14:09:40 [INFO] Successfully returned JSON output
# 14:09:40 [INFO] Parsed kills to Pandas DataFrame
# 14:09:40 [INFO] Parsed rounds to Pandas DataFrame
# 14:09:40 [INFO] Parsed damages to Pandas DataFrame

# %%
for x in range(len(infernoKills)):
    if(infernoKills[x].shape[0] < 100):
        print("failed demo " + str(x))

# %%
infernoKill = concat_data(infernoKills)
infernoRound = concat_data(infernoROunds)
infernoDamage = concat_data(infernoDamages)

# %%
for x in range(len(infernoKill)):
    if  infernoKill.iloc[x]['AttackerAreaName'] != None:
        if infernoKill.iloc[x]['AttackerAreaName'] in mappedPlaceNames:
            infernoKill.at[x, 'AttackerAreaName'] = mappedPlaceNames[infernoKill.iloc[x]['AttackerAreaName']]
        if infernoKill.iloc[x]['VictimAreaName'] in mappedPlaceNames:
            infernoKill.at[x, 'VictimAreaName'] = mappedPlaceNames[infernoKill.iloc[x]['VictimAreaName']]

for x in range(len(infernoDamage)):
    if  infernoDamage.iloc[x]['AttackerAreaName'] != None:
        if infernoDamage.iloc[x]['AttackerAreaName'] in mappedPlaceNames:
            infernoDamage.at[x, 'AttackerAreaName'] = mappedPlaceNames[infernoDamage.iloc[x]['AttackerAreaName']]
        if infernoDamage.iloc[x]['VictimAreaName'] in mappedPlaceNames:
            infernoDamage.at[x, 'VictimAreaName'] = mappedPlaceNames[infernoDamage.iloc[x]['VictimAreaName']]

# %%
player_names = list(infernoKill.AttackerName.value_counts().index)
player_name = {}
for x in player_names:
    player_name[x] = [x]

# %%
infernoDifferentials = createSidedCSVDF(player_name, infernoDamage, infernoKill, infernoRound)
# Out:
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
infernoDifferentials[infernoDifferentials['Location'] == 'BombsiteB']
# Out:
#        Location     Player  Kills  Deaths  K/D  Damage Dealt  Damage Taken  \
# 3856  BombsiteB  MiGHTYMAX      0       0    0             0             0
# 3857  BombsiteB  MiGHTYMAX      0       1   -1             0             8
# 5356  BombsiteB      JACKZ      0       0    0             0             0
# 5357  BombsiteB      JACKZ      0       1   -1             0             4
#
#       Damage Differential Side  Total Rounds
# 3856                    0   CT           133
# 3857                   -8    T           133
# 5356                    0   CT            59
# 5357                   -4    T            59

# %%
mappedPlaceNames
# Out:
# {'AbovePit': 'Deep T Spawn',
#  'Admin': 'T Ramp Ledge',
#  'PalaceInterior': 'T Ramp Peeking Towards Mid',
#  'Airplane': 'Bottom Mid exposed to Top Mid',
#  'Alley': 'Bottom Mid Banana',
#  'APlatform': 'Banana',
#  'Arch': 'CT Arch',
#  'Atrium': 'Logs',
#  'Attic': 'Chokepoint Entering B',
#  'Back': 'Grill',
#  'BackAlley': 'CT Peek Towards B Choke',
#  'BackAlleys': '1st Oranges',
#  'BackCourtyard': '2nd Oranges',
#  'BackDoor': 'Quad Box',
#  'BackEntrance': 'Fountain',
#  'BackHall': 'Dark',
#  'BackofA': 'Coffins',
#  'BackofB': 'Garden',
#  'BackRoad': 'Construction',
#  'BackRoom': 'Construction Sandbags',
#  'BackWay': 'CT Truck',
#  'BackYard': 'CT Tree',
#  'Banana': 'CT Near Well',
#  'BankExterior': 'CT Spawn ',
#  'BankInterior': 'CT Speed Way',
#  'Barn': 'CT Outside Arch',
#  'BarnRoof': 'CT Outside Kitchen',
#  'Basement': 'CT Arch',
#  'Bathroom': 'Arch Side Cubby',
#  'BDoors': 'Arch Side',
#  'Beach': 'Library',
#  'Bedroom': 'Top Mid Arch Side',
#  'BigForest': 'Top Mid Lane Side ',
#  'BigOffice': 'Top Mid',
#  'BoatBar': 'Lane',
#  'BoatHouse': 'Patio',
#  'BoatStorage': 'Pit Peek Towards Lane',
#  'BodyShop': 'Top Apps Balcony',
#  'BombSite': 'Pit Below Balcony',
#  'BombsiteA': 'Boiler Side Stairs',
#  'BombsiteB': 'Apps T Side Stairs',
#  'BombsiteC': 'Boiler Peek to Mid',
#  'BPlatform': 'Boiler Room',
#  'Bricks': 'Second Mid Close Apps',
#  'Bridge': 'Second Mid',
#  'Bunker': 'Living Room',
#  'Canal': 'Balcony',
#  'Cart': 'T Apps',
#  'Catwalk': 'Back Alley',
#  'ComputerRoom': 'CT Banana Barrels',
#  'ConferenceRoom': 'CT Banana Half Wall Side',
#  'Connector': 'CT Banana Close Left Half Wall',
#  'Construction': 'CT Banana Sandbangs',
#  'Control': 'CT Banana Sandbags Right Corner',
#  'Courtyard': 'Bottom Mid Ladder Room Peek',
#  'Crane': "B Site Cross for T's Exposed to CT and Quad",
#  'Crates': 'B Site',
#  'Crawlspace': 'Right Side Quadbox Peek for a CT',
#  'Crows': 'Behind B Site Back Pillar',
#  'CTCorridorDown': 'Left Side Quadbox Peek for a CT',
#  'CTCorridorUp': 'Top Coffins',
#  'CTBar': 'Front Coffins',
#  'CTRed': 'Behind Coffins Playing the B Site Cross',
#  'CTSideLower': 'CT Boost',
#  'CTSideUpper': 'CT Tree',
#  'CTSpawn': 'CT Outside Construction',
#  'DeadTrees': 'Deep CT Peeking Towards B Site',
#  'Deck': 'Arch Side CT Corner Peeking Towards Top Mid',
#  'Decon': 'Outside Library',
#  'Den': 'Next to Library Cubby',
#  'DirtRoad': 'Chokepoint Entrance onto A site from Library Side',
#  'DoubleDoors': 'Top Graveyard',
#  'Downstairs': 'Graveyard Stairs',
#  'DriveWay': 'Bottom Graveyard',
#  'Ducts': 'Pit Dosia Corner',
#  'Dumpster': 'Pit',
#  'EastForest': 'Top Balcony ',
#  'ElectricalBox': 'Top Hay Bales',
#  'Elevator': 'Lane Side',
#  'Entrance': 'Lane Peek Towards Top Mid',
#  'Entryway': 'Lane Behind Pillar',
#  'ExtendedA': 'Lane Patio',
#  'FamilyRoom': 'Top Mid Chokepoint',
#  'FarSide': 'Deep Apps Past Hallway',
#  'Field': 'Apps Hallway',
#  'Floor50': 'Apartments Cubby',
#  'Floor51': 'Apartments Hallway Peek from T Side',
#  'Forklift': 'T Apps Bridge ',
#  'Fountain': 'Deck',
#  'Foyer': 'Default Plant A Site',
#  'Front': 'A Bombsite Close Left',
#  'FrontCourtyard': 'A Bombsite Back Site',
#  'FrontDoor': 'A Site Behind Middle Boxes/Pillar hidden from Lane',
#  'FrontEntrance': 'A Site Left Side Middle Boxes',
#  'FrontHall': 'A Site Behind Default Boxes',
#  'FrontRoom': 'A Site',
#  'FrontYard': 'A Site Right Side Middle Pillar'}

# %%
infernoDifferentials
# Out:
#                      Location    Player  Kills  Deaths  K/D  Damage Dealt  \
# 0                   Lane Side     Ax1Le      5       2    3           523
# 1                   Lane Side     Ax1Le      2       2    0           323
# 2                Top Balcony      Ax1Le      4       4    0           647
# 3                Top Balcony      Ax1Le      5       6   -1           458
# 4          Top Mid Chokepoint     Ax1Le      2       1    1           336
# ...                       ...       ...    ...     ...  ...           ...
# 8029                 Quad Box  pesadelo      0       1   -1             0
# 8030    A Bombsite Close Left  pesadelo      0       0    0             0
# 8031    A Bombsite Close Left  pesadelo      0       0    0             0
# 8032  CT Peek Towards B Choke  pesadelo      0       0    0             0
# 8033  CT Peek Towards B Choke  pesadelo      0       0    0             0
#
#       Damage Taken  Damage Differential Side  Total Rounds
# 0              200                  323   CT           160
# 1              378                  -55    T           160
# 2              481                  166   CT           160
# 3              532                  -74    T           160
# 4              176                  160   CT           160
# ...            ...                  ...  ...           ...
# 8029            68                  -68    T            21
# 8030             0                    0   CT            21
# 8031             6                   -6    T            21
# 8032             0                    0   CT            21
# 8033             0                    0    T            21
#
# [8034 rows x 10 columns]

# %%
infernoDifferentials.to_csv(output_path)

# %%
print(output_path)
# Out:
# ./damageDifferentials/epls13/eslInfernoDifferentials.csv

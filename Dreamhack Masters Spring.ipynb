# %%
from csgo.parser import DemoParser
import numpy
import csv
import pandas
import pyserialem
import os
from tabulate import tabulate

# %%
def getDemoPaths(dir_path):
    demoPaths = []
    x = 0
    for filename in os.listdir(dir_path):
        demoPaths.append(os.path.join(dir_path, filename))
    return demoPaths

# %%
def generateDemoParsers(paths):
    demo_parsers = []
    for x in paths:
        demoParser = DemoParser(demofile=x, demo_id = x.split('/')[-1].split('.')[0].split('_')[0], parse_rate=128)
        demo_parsers.append(demoParser)
    print("# Demo Parsers: " + str(len(demo_parsers)))
    return demo_parsers

# %%
def generateData(parsers):
    mapData, killData, nadeData, flashData, roundData, damageData = [], [], [], [], [], []
    for x in parsers:
        x.parse()
        mapData.append(x.parse(return_type="df"))
        killData.append(x._parse_kills(return_type="df"))
        nadeData.append(x._parse_grenades(return_type="df"))
        flashData.append(x._parse_flashes(return_type="df"))
        roundData.append(x._parse_rounds(return_type="df"))
        damageData.append(x._parse_damages(return_type="df"))
    return (mapData, killData, nadeData, flashData, roundData, damageData)

# %%
def concat_data(aggregate_data):
    final_df = None
    for x in aggregate_data:
        final_df = pandas.concat([final_df, x], ignore_index=True)
    return final_df

# %%
def createSidedCSVDF(players, damageData, killData, roundData):
    locationNames = []
    playerNames = []

    Kills = []
    Deaths = []
    KdDifferential = []
    DamageDealt = []
    DamageTaken = []
    DamageDifferential = []
    sides = []
    totalRounds = []
    dataframe = {}
    for x in players.keys():
        for y in killData[killData['AttackerName'].isin(players[x]) | killData['VictimName'].isin(players[x])].VictimAreaName.value_counts().index:
            
            tempCTKills = len(killData[killData['AttackerName'].isin(players[x])][killData['AttackerAreaName'] == y][killData['AttackerSide'] == 'CT'])
            tempCTDeaths = len(killData[killData['VictimName'].isin(players[x])][killData['VictimAreaName'] == y][killData['VictimSide'] == 'CT'])
            tempCTKdDifferential = tempCTKills - tempCTDeaths
            
            tempCTDamageDealt = damageData[damageData['AttackerName'].isin(players[x])][damageData['AttackerAreaName'] == y][damageData['AttackerSide'] == 'CT'].HpDamageTaken.sum()
            tempCTDamageTaken = damageData[damageData['VictimName'].isin(players[x])][damageData['VictimAreaName'] == y][damageData['VictimSide'] == 'CT'].HpDamageTaken.sum()
            tempCTDamageDifferential = tempCTDamageDealt - tempCTDamageTaken
                                                                                                             
            tempTKills = len(killData[killData['AttackerName'].isin(players[x])][killData['AttackerAreaName'] == y][killData['AttackerSide'] == 'T'])
            tempTDeaths = len(killData[killData['VictimName'].isin(players[x])][killData['VictimAreaName'] == y][killData['VictimSide'] == 'T'])
            tempTKdDifferential = tempTKills - tempTDeaths
                                                                                                             
            tempTDamageDealt = damageData[damageData['AttackerName'].isin(players[x])][damageData['AttackerAreaName'] == y][damageData['AttackerSide'] == 'T'].HpDamageTaken.sum()
            tempTDamageTaken = damageData[damageData['VictimName'].isin(players[x])][damageData['VictimAreaName'] == y][damageData['VictimSide'] == 'T'].HpDamageTaken.sum()
            tempTDamageDifferential = tempTDamageDealt - tempTDamageTaken
            
            tempTotalRounds = 0
                                                    
            for z in killData[killData.AttackerName.isin(players[x])].MatchId.value_counts().index:
                tempTotalRounds += roundData[roundData['MatchId'] == z].iloc[-1].RoundNum
            
            locationNames.append(y)
            locationNames.append(y)
            
            playerNames.append(x)
            playerNames.append(x)
            
            Kills.append(tempCTKills)
            Kills.append(tempTKills)
            
            
            Deaths.append(tempCTDeaths)
            Deaths.append(tempTDeaths)
            
            
            KdDifferential.append(tempCTKdDifferential)
            KdDifferential.append(tempTKdDifferential)
            
            
            DamageDealt.append(tempCTDamageDealt)
            DamageTaken.append(tempCTDamageTaken)
            DamageDifferential.append(tempCTDamageDifferential)
            
            DamageDealt.append(tempTDamageDealt)
            DamageTaken.append(tempTDamageTaken)
            DamageDifferential.append(tempTDamageDifferential)
            
            sides.append('CT')
            sides.append('T')
            
            
            totalRounds.append(tempTotalRounds)
            totalRounds.append(tempTotalRounds)
    
    dataframe['Location'] = locationNames
    dataframe['Player'] = playerNames
    dataframe['Kills'] = Kills
    dataframe['Deaths'] = Deaths
    dataframe['K/D'] = KdDifferential
    dataframe['Damage Dealt'] = DamageDealt
    dataframe['Damage Taken'] = DamageTaken
    dataframe['Damage Differential'] = DamageDifferential
    dataframe['Side'] = sides
    dataframe['Total Rounds'] = totalRounds
    
    return pandas.DataFrame.from_dict(dataframe, orient='columns')

# %%
dir_path = "./demos/Dreamhack"

# %%
dreamhack_output_path = './damageDifferentials/Dreamhack/dreamhackMirageDamageDifferentials.csv'
kills_output_path = './damageDifferentials/Dreamhack/killsDreamhack.csv'
damages_output_path = './damageDifferentials/Dreamhack/damagesDreamhack.csv'
rounds_output_path = './damageDifferentials/Dreamhack/roundsDreamhack.csv'

# %%
mirageMappingPath = './mappings/mappings/'

# %%
mappingFile = os.path.join(mirageMappingPath, os.listdir(mirageMappingPath)[0])

# %%
file = open(mappingFile, 'r')
lines = file.readlines()
file.close()

# %%
for x in range(len(lines)):
    if(lines[x][-1] == '\n'):
        lines[x] = lines[x][:-1]

# %%
mappedPlaceNames = {}
for x in lines:
    if(x != ''):
            mappedPlaceNames[x.split(':')[0]] = x.split(':')[1]

# %%
demoPaths = getDemoPaths(dir_path)

# %%
len(demoPaths)
# Out:
# 42

# %%
demoParsers = generateDemoParsers(demoPaths)
# Out:
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-complexity-m2-inferno.dem
# 17:57:42 [INFO] Setting demo id to astralis-vs-complexity-m2-inferno
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-extra-salt-nuke.dem
# 17:57:42 [INFO] Setting demo id to astralis-vs-extra-salt-nuke
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-heroic-m2-inferno.dem
# 17:57:42 [INFO] Setting demo id to astralis-vs-heroic-m2-inferno
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/extra-salt-vs-vitality-m3-nuke.dem
# 17:57:42 [INFO] Setting demo id to extra-salt-vs-vitality-m3-nuke
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/faze-vs-virtus-pro-train.dem
# 17:57:42 [INFO] Setting demo id to faze-vs-virtus-pro-train
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/fiend-vs-spirit-m2-overpass.dem
# 17:57:42 [INFO] Setting demo id to fiend-vs-spirit-m2-overpass
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/fiend-vs-spirit-m3-nuke.dem
# 17:57:42 [INFO] Setting demo id to fiend-vs-spirit-m3-nuke
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-complexity-m2-inferno.dem
# 17:57:42 [INFO] Setting demo id to furia-vs-complexity-m2-inferno
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-natus-vincere-m1-inferno.dem
# 17:57:42 [INFO] Setting demo id to furia-vs-natus-vincere-m1-inferno
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-natus-vincere-m3-mirage.dem
# 17:57:42 [INFO] Setting demo id to furia-vs-natus-vincere-m3-mirage
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-pain-m1-nuke.dem
# 17:57:42 [INFO] Setting demo id to furia-vs-pain-m1-nuke
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:42 [INFO] Go version>=1.14.0
# 17:57:42 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-pain-m2-mirage.dem
# 17:57:42 [INFO] Setting demo id to furia-vs-pain-m2-mirage
# 17:57:42 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-astralis-m1-train.dem
# 17:57:43 [INFO] Setting demo id to g2-vs-astralis-m1-train
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-astralis-m3-vertigo.dem
# 17:57:43 [INFO] Setting demo id to g2-vs-astralis-m3-vertigo
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-mousesports-m1-vertigo_1.dem
# 17:57:43 [INFO] Setting demo id to g2-vs-mousesports-m1-vertigo
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-fiend-dust2.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-fiend-dust2
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m1-inferno.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-g2-m1-inferno
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m2-train.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-g2-m2-train
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m2-vertigo.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-g2-m2-vertigo
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m3-dust2.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-g2-m3-dust2
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-natus-vincere-m2-overpass.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-natus-vincere-m2-overpass
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-natus-vincere-m3-mirage.dem
# 17:57:43 [INFO] Setting demo id to gambit-vs-natus-vincere-m3-mirage
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:43 [INFO] Go version>=1.14.0
# 17:57:43 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m1-mirage.dem
# 17:57:43 [INFO] Setting demo id to heroic-vs-natus-vincere-m1-mirage
# 17:57:43 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m2-nuke.dem
# 17:57:44 [INFO] Setting demo id to heroic-vs-natus-vincere-m2-nuke
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m2-nuke_1.dem
# 17:57:44 [INFO] Setting demo id to heroic-vs-natus-vincere-m2-nuke
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m3-inferno.dem
# 17:57:44 [INFO] Setting demo id to heroic-vs-natus-vincere-m3-inferno
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m3-inferno_1.dem
# 17:57:44 [INFO] Setting demo id to heroic-vs-natus-vincere-m3-inferno
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/mousesports-vs-faze-m1-mirage.dem
# 17:57:44 [INFO] Setting demo id to mousesports-vs-faze-m1-mirage
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/mousesports-vs-faze-m2-nuke.dem
# 17:57:44 [INFO] Setting demo id to mousesports-vs-faze-m2-nuke
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/mousesports-vs-faze-m3-overpass.dem
# 17:57:44 [INFO] Setting demo id to mousesports-vs-faze-m3-overpass
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/natus-vincere-vs-mousesports-overpass.dem
# 17:57:44 [INFO] Setting demo id to natus-vincere-vs-mousesports-overpass
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/natus-vincere-vs-virtus-pro-m1-dust2.dem
# 17:57:44 [INFO] Setting demo id to natus-vincere-vs-virtus-pro-m1-dust2
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/natus-vincere-vs-virtus-pro-m2-inferno.dem
# 17:57:44 [INFO] Setting demo id to natus-vincere-vs-virtus-pro-m2-inferno
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/pain-vs-heroic-nuke.dem
# 17:57:44 [INFO] Setting demo id to pain-vs-heroic-nuke
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:44 [INFO] Go version>=1.14.0
# 17:57:44 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/spirit-vs-g2-mirage.dem
# 17:57:44 [INFO] Setting demo id to spirit-vs-g2-mirage
# 17:57:44 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/spirit-vs-virtus-pro-m2-inferno.dem
# 17:57:45 [INFO] Setting demo id to spirit-vs-virtus-pro-m2-inferno
# 17:57:45 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/virtus-pro-vs-g2-m1-vertigo.dem
# 17:57:45 [INFO] Setting demo id to virtus-pro-vs-g2-m1-vertigo
# 17:57:45 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/virtus-pro-vs-g2-m2-inferno.dem
# 17:57:45 [INFO] Setting demo id to virtus-pro-vs-g2-m2-inferno
# 17:57:45 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-big-m1-mirage.dem
# 17:57:45 [INFO] Setting demo id to vitality-vs-big-m1-mirage
# 17:57:45 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-big-m2-nuke.dem
# 17:57:45 [INFO] Setting demo id to vitality-vs-big-m2-nuke
# 17:57:45 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-furia-m1-vertigo.dem
# 17:57:45 [INFO] Setting demo id to vitality-vs-furia-m1-vertigo
# 17:57:45 [INFO] Setting parse rate to 128
# 17:57:45 [INFO] Go version>=1.14.0
# 17:57:45 [INFO] Initialized CSGODemoParser with demofile /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-furia-m2-nuke.dem
# 17:57:45 [INFO] Setting demo id to vitality-vs-furia-m2-nuke
# 17:57:45 [INFO] Setting parse rate to 128
# # Demo Parsers: 42

# %%
maps, kills, nades, flashs, rounds, damages = generateData(demoParsers)
# Out:
# 17:57:46 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:57:46 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-complexity-m2-inferno.dem
# 17:58:19 [INFO] Wrote demo parse output to astralis-vs-complexity-m2-inferno.json
# 17:58:19 [INFO] Reading in JSON from astralis-vs-complexity-m2-inferno.json
# 17:58:20 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:58:20 [INFO] Successfully parsed JSON output
# 17:58:20 [INFO] Successfully returned JSON output
# 17:58:20 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:58:20 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-complexity-m2-inferno.dem
# 17:58:48 [INFO] Wrote demo parse output to astralis-vs-complexity-m2-inferno.json
# 17:58:48 [INFO] Reading in JSON from astralis-vs-complexity-m2-inferno.json
# 17:58:49 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:58:49 [INFO] Successfully parsed JSON output
# 17:58:49 [INFO] Successfully returned JSON output
# 17:58:49 [INFO] Parsed rounds to Pandas DataFrame
# 17:58:50 [INFO] Parsed kills to Pandas DataFrame
# 17:58:50 [INFO] Parsed damages to Pandas DataFrame
# 17:58:50 [INFO] Parsed grenades to Pandas DataFrame
# 17:58:50 [INFO] Parsed flashes to Pandas DataFrame
# 17:58:50 [INFO] Parsed bomb_events to Pandas DataFrame
# 17:58:50 [INFO] Parsed frames to Pandas DataFrame
# 17:58:50 [INFO] Parsed player frames to Pandas DataFrame
# 17:58:50 [INFO] Returned dataframe output
# 17:58:50 [INFO] Parsed kills to Pandas DataFrame
# 17:58:50 [INFO] Parsed grenades to Pandas DataFrame
# 17:58:50 [INFO] Parsed flashes to Pandas DataFrame
# 17:58:50 [INFO] Parsed rounds to Pandas DataFrame
# 17:58:50 [INFO] Parsed damages to Pandas DataFrame
# 17:58:50 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:58:50 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-extra-salt-nuke.dem
# 17:59:09 [INFO] Wrote demo parse output to astralis-vs-extra-salt-nuke.json
# 17:59:09 [INFO] Reading in JSON from astralis-vs-extra-salt-nuke.json
# 17:59:09 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:59:09 [INFO] Successfully parsed JSON output
# 17:59:09 [INFO] Successfully returned JSON output
# 17:59:09 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:59:09 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-extra-salt-nuke.dem
# 17:59:26 [INFO] Wrote demo parse output to astralis-vs-extra-salt-nuke.json
# 17:59:26 [INFO] Reading in JSON from astralis-vs-extra-salt-nuke.json
# 17:59:27 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:59:27 [INFO] Successfully parsed JSON output
# 17:59:27 [INFO] Successfully returned JSON output
# 17:59:27 [INFO] Parsed rounds to Pandas DataFrame
# 17:59:27 [INFO] Parsed kills to Pandas DataFrame
# 17:59:27 [INFO] Parsed damages to Pandas DataFrame
# 17:59:27 [INFO] Parsed grenades to Pandas DataFrame
# 17:59:27 [INFO] Parsed flashes to Pandas DataFrame
# 17:59:27 [INFO] Parsed bomb_events to Pandas DataFrame
# 17:59:27 [INFO] Parsed frames to Pandas DataFrame
# 17:59:27 [INFO] Parsed player frames to Pandas DataFrame
# 17:59:27 [INFO] Returned dataframe output
# 17:59:27 [INFO] Parsed kills to Pandas DataFrame
# 17:59:27 [INFO] Parsed grenades to Pandas DataFrame
# 17:59:27 [INFO] Parsed flashes to Pandas DataFrame
# 17:59:27 [INFO] Parsed rounds to Pandas DataFrame
# 17:59:27 [INFO] Parsed damages to Pandas DataFrame
# 17:59:27 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:59:27 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-heroic-m2-inferno.dem
# 17:59:41 [INFO] Wrote demo parse output to astralis-vs-heroic-m2-inferno.json
# 17:59:41 [INFO] Reading in JSON from astralis-vs-heroic-m2-inferno.json
# 17:59:41 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:59:41 [INFO] Successfully parsed JSON output
# 17:59:41 [INFO] Successfully returned JSON output
# 17:59:41 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:59:41 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/astralis-vs-heroic-m2-inferno.dem
# 17:59:56 [INFO] Wrote demo parse output to astralis-vs-heroic-m2-inferno.json
# 17:59:56 [INFO] Reading in JSON from astralis-vs-heroic-m2-inferno.json
# 17:59:56 [INFO] JSON data loaded, available in the `json` attribute to parser
# 17:59:56 [INFO] Successfully parsed JSON output
# 17:59:56 [INFO] Successfully returned JSON output
# 17:59:56 [INFO] Parsed rounds to Pandas DataFrame
# 17:59:56 [INFO] Parsed kills to Pandas DataFrame
# 17:59:56 [INFO] Parsed damages to Pandas DataFrame
# 17:59:56 [INFO] Parsed grenades to Pandas DataFrame
# 17:59:56 [INFO] Parsed flashes to Pandas DataFrame
# 17:59:56 [INFO] Parsed bomb_events to Pandas DataFrame
# 17:59:56 [INFO] Parsed frames to Pandas DataFrame
# 17:59:56 [INFO] Parsed player frames to Pandas DataFrame
# 17:59:56 [INFO] Returned dataframe output
# 17:59:56 [INFO] Parsed kills to Pandas DataFrame
# 17:59:56 [INFO] Parsed grenades to Pandas DataFrame
# 17:59:56 [INFO] Parsed flashes to Pandas DataFrame
# 17:59:56 [INFO] Parsed rounds to Pandas DataFrame
# 17:59:56 [INFO] Parsed damages to Pandas DataFrame
# 17:59:56 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 17:59:56 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/extra-salt-vs-vitality-m3-nuke.dem
# 18:00:14 [INFO] Wrote demo parse output to extra-salt-vs-vitality-m3-nuke.json
# 18:00:14 [INFO] Reading in JSON from extra-salt-vs-vitality-m3-nuke.json
# 18:00:14 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:00:14 [INFO] Successfully parsed JSON output
# 18:00:14 [INFO] Successfully returned JSON output
# 18:00:14 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:00:14 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/extra-salt-vs-vitality-m3-nuke.dem
# 18:00:31 [INFO] Wrote demo parse output to extra-salt-vs-vitality-m3-nuke.json
# 18:00:31 [INFO] Reading in JSON from extra-salt-vs-vitality-m3-nuke.json
# 18:00:32 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:00:32 [INFO] Successfully parsed JSON output
# 18:00:32 [INFO] Successfully returned JSON output
# 18:00:32 [INFO] Parsed rounds to Pandas DataFrame
# 18:00:32 [INFO] Parsed kills to Pandas DataFrame
# 18:00:32 [INFO] Parsed damages to Pandas DataFrame
# 18:00:32 [INFO] Parsed grenades to Pandas DataFrame
# 18:00:32 [INFO] Parsed flashes to Pandas DataFrame
# 18:00:32 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:00:32 [INFO] Parsed frames to Pandas DataFrame
# 18:00:32 [INFO] Parsed player frames to Pandas DataFrame
# 18:00:32 [INFO] Returned dataframe output
# 18:00:32 [INFO] Parsed kills to Pandas DataFrame
# 18:00:32 [INFO] Parsed grenades to Pandas DataFrame
# 18:00:32 [INFO] Parsed flashes to Pandas DataFrame
# 18:00:32 [INFO] Parsed rounds to Pandas DataFrame
# 18:00:32 [INFO] Parsed damages to Pandas DataFrame
# 18:00:32 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:00:32 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/faze-vs-virtus-pro-train.dem
# 18:00:49 [INFO] Wrote demo parse output to faze-vs-virtus-pro-train.json
# 18:00:49 [INFO] Reading in JSON from faze-vs-virtus-pro-train.json
# 18:00:49 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:00:49 [INFO] Successfully parsed JSON output
# 18:00:49 [INFO] Successfully returned JSON output
# 18:00:49 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:00:49 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/faze-vs-virtus-pro-train.dem
# 18:01:06 [INFO] Wrote demo parse output to faze-vs-virtus-pro-train.json
# 18:01:06 [INFO] Reading in JSON from faze-vs-virtus-pro-train.json
# 18:01:07 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:01:07 [INFO] Successfully parsed JSON output
# 18:01:07 [INFO] Successfully returned JSON output
# 18:01:07 [INFO] Parsed rounds to Pandas DataFrame
# 18:01:07 [INFO] Parsed kills to Pandas DataFrame
# 18:01:07 [INFO] Parsed damages to Pandas DataFrame
# 18:01:07 [INFO] Parsed grenades to Pandas DataFrame
# 18:01:07 [INFO] Parsed flashes to Pandas DataFrame
# 18:01:07 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:01:07 [INFO] Parsed frames to Pandas DataFrame
# 18:01:07 [INFO] Parsed player frames to Pandas DataFrame
# 18:01:07 [INFO] Returned dataframe output
# 18:01:07 [INFO] Parsed kills to Pandas DataFrame
# 18:01:07 [INFO] Parsed grenades to Pandas DataFrame
# 18:01:07 [INFO] Parsed flashes to Pandas DataFrame
# 18:01:07 [INFO] Parsed rounds to Pandas DataFrame
# 18:01:07 [INFO] Parsed damages to Pandas DataFrame
# 18:01:07 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:01:07 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/fiend-vs-spirit-m2-overpass.dem
# 18:01:46 [INFO] Wrote demo parse output to fiend-vs-spirit-m2-overpass.json
# 18:01:46 [INFO] Reading in JSON from fiend-vs-spirit-m2-overpass.json
# 18:01:47 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:01:47 [INFO] Successfully parsed JSON output
# 18:01:47 [INFO] Successfully returned JSON output
# 18:01:47 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:01:47 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/fiend-vs-spirit-m2-overpass.dem
# 18:02:27 [INFO] Wrote demo parse output to fiend-vs-spirit-m2-overpass.json
# 18:02:27 [INFO] Reading in JSON from fiend-vs-spirit-m2-overpass.json
# 18:02:27 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:02:27 [INFO] Successfully parsed JSON output
# 18:02:27 [INFO] Successfully returned JSON output
# 18:02:27 [INFO] Parsed rounds to Pandas DataFrame
# 18:02:28 [INFO] Parsed kills to Pandas DataFrame
# 18:02:28 [INFO] Parsed damages to Pandas DataFrame
# 18:02:28 [INFO] Parsed grenades to Pandas DataFrame
# 18:02:28 [INFO] Parsed flashes to Pandas DataFrame
# 18:02:28 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:02:28 [INFO] Parsed frames to Pandas DataFrame
# 18:02:28 [INFO] Parsed player frames to Pandas DataFrame
# 18:02:28 [INFO] Returned dataframe output
# 18:02:28 [INFO] Parsed kills to Pandas DataFrame
# 18:02:28 [INFO] Parsed grenades to Pandas DataFrame
# 18:02:28 [INFO] Parsed flashes to Pandas DataFrame
# 18:02:28 [INFO] Parsed rounds to Pandas DataFrame
# 18:02:28 [INFO] Parsed damages to Pandas DataFrame
# 18:02:28 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:02:28 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/fiend-vs-spirit-m3-nuke.dem
# 18:02:45 [INFO] Wrote demo parse output to fiend-vs-spirit-m3-nuke.json
# 18:02:45 [INFO] Reading in JSON from fiend-vs-spirit-m3-nuke.json
# 18:02:45 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:02:45 [INFO] Successfully parsed JSON output
# 18:02:45 [INFO] Successfully returned JSON output
# 18:02:45 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:02:45 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/fiend-vs-spirit-m3-nuke.dem
# 18:03:03 [INFO] Wrote demo parse output to fiend-vs-spirit-m3-nuke.json
# 18:03:03 [INFO] Reading in JSON from fiend-vs-spirit-m3-nuke.json
# 18:03:03 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:03:03 [INFO] Successfully parsed JSON output
# 18:03:03 [INFO] Successfully returned JSON output
# 18:03:03 [INFO] Parsed rounds to Pandas DataFrame
# 18:03:03 [INFO] Parsed kills to Pandas DataFrame
# 18:03:03 [INFO] Parsed damages to Pandas DataFrame
# 18:03:03 [INFO] Parsed grenades to Pandas DataFrame
# 18:03:03 [INFO] Parsed flashes to Pandas DataFrame
# 18:03:03 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:03:03 [INFO] Parsed frames to Pandas DataFrame
# 18:03:03 [INFO] Parsed player frames to Pandas DataFrame
# 18:03:03 [INFO] Returned dataframe output
# 18:03:03 [INFO] Parsed kills to Pandas DataFrame
# 18:03:03 [INFO] Parsed grenades to Pandas DataFrame
# 18:03:03 [INFO] Parsed flashes to Pandas DataFrame
# 18:03:03 [INFO] Parsed rounds to Pandas DataFrame
# 18:03:03 [INFO] Parsed damages to Pandas DataFrame
# 18:03:03 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:03:03 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-complexity-m2-inferno.dem
# 18:03:20 [INFO] Wrote demo parse output to furia-vs-complexity-m2-inferno.json
# 18:03:20 [INFO] Reading in JSON from furia-vs-complexity-m2-inferno.json
# 18:03:21 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:03:21 [INFO] Successfully parsed JSON output
# 18:03:21 [INFO] Successfully returned JSON output
# 18:03:21 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:03:21 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-complexity-m2-inferno.dem
# 18:03:38 [INFO] Wrote demo parse output to furia-vs-complexity-m2-inferno.json
# 18:03:38 [INFO] Reading in JSON from furia-vs-complexity-m2-inferno.json
# 18:03:39 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:03:39 [INFO] Successfully parsed JSON output
# 18:03:39 [INFO] Successfully returned JSON output
# 18:03:39 [INFO] Parsed rounds to Pandas DataFrame
# 18:03:39 [INFO] Parsed kills to Pandas DataFrame
# 18:03:39 [INFO] Parsed damages to Pandas DataFrame
# 18:03:39 [INFO] Parsed grenades to Pandas DataFrame
# 18:03:39 [INFO] Parsed flashes to Pandas DataFrame
# 18:03:39 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:03:39 [INFO] Parsed frames to Pandas DataFrame
# 18:03:39 [INFO] Parsed player frames to Pandas DataFrame
# 18:03:39 [INFO] Returned dataframe output
# 18:03:39 [INFO] Parsed kills to Pandas DataFrame
# 18:03:39 [INFO] Parsed grenades to Pandas DataFrame
# 18:03:39 [INFO] Parsed flashes to Pandas DataFrame
# 18:03:39 [INFO] Parsed rounds to Pandas DataFrame
# 18:03:39 [INFO] Parsed damages to Pandas DataFrame
# 18:03:39 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:03:39 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-natus-vincere-m1-inferno.dem
# 18:04:08 [INFO] Wrote demo parse output to furia-vs-natus-vincere-m1-inferno.json
# 18:04:08 [INFO] Reading in JSON from furia-vs-natus-vincere-m1-inferno.json
# 18:04:08 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:04:08 [INFO] Successfully parsed JSON output
# 18:04:08 [INFO] Successfully returned JSON output
# 18:04:08 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:04:08 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-natus-vincere-m1-inferno.dem
# 18:04:37 [INFO] Wrote demo parse output to furia-vs-natus-vincere-m1-inferno.json
# 18:04:37 [INFO] Reading in JSON from furia-vs-natus-vincere-m1-inferno.json
# 18:04:38 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:04:38 [INFO] Successfully parsed JSON output
# 18:04:38 [INFO] Successfully returned JSON output
# 18:04:38 [INFO] Parsed rounds to Pandas DataFrame
# 18:04:38 [INFO] Parsed kills to Pandas DataFrame
# 18:04:38 [INFO] Parsed damages to Pandas DataFrame
# 18:04:38 [INFO] Parsed grenades to Pandas DataFrame
# 18:04:38 [INFO] Parsed flashes to Pandas DataFrame
# 18:04:38 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:04:38 [INFO] Parsed frames to Pandas DataFrame
# 18:04:38 [INFO] Parsed player frames to Pandas DataFrame
# 18:04:38 [INFO] Returned dataframe output
# 18:04:38 [INFO] Parsed kills to Pandas DataFrame
# 18:04:38 [INFO] Parsed grenades to Pandas DataFrame
# 18:04:38 [INFO] Parsed flashes to Pandas DataFrame
# 18:04:38 [INFO] Parsed rounds to Pandas DataFrame
# 18:04:38 [INFO] Parsed damages to Pandas DataFrame
# 18:04:38 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:04:38 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-natus-vincere-m3-mirage.dem
# 18:04:54 [INFO] Wrote demo parse output to furia-vs-natus-vincere-m3-mirage.json
# 18:04:54 [INFO] Reading in JSON from furia-vs-natus-vincere-m3-mirage.json
# 18:04:54 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:04:54 [INFO] Successfully parsed JSON output
# 18:04:54 [INFO] Successfully returned JSON output
# 18:04:54 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:04:54 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-natus-vincere-m3-mirage.dem
# 18:05:09 [INFO] Wrote demo parse output to furia-vs-natus-vincere-m3-mirage.json
# 18:05:09 [INFO] Reading in JSON from furia-vs-natus-vincere-m3-mirage.json
# 18:05:10 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:05:10 [INFO] Successfully parsed JSON output
# 18:05:10 [INFO] Successfully returned JSON output
# 18:05:10 [INFO] Parsed rounds to Pandas DataFrame
# 18:05:10 [INFO] Parsed kills to Pandas DataFrame
# 18:05:10 [INFO] Parsed damages to Pandas DataFrame
# 18:05:10 [INFO] Parsed grenades to Pandas DataFrame
# 18:05:10 [INFO] Parsed flashes to Pandas DataFrame
# 18:05:10 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:05:10 [INFO] Parsed frames to Pandas DataFrame
# 18:05:10 [INFO] Parsed player frames to Pandas DataFrame
# 18:05:10 [INFO] Returned dataframe output
# 18:05:10 [INFO] Parsed kills to Pandas DataFrame
# 18:05:10 [INFO] Parsed grenades to Pandas DataFrame
# 18:05:10 [INFO] Parsed flashes to Pandas DataFrame
# 18:05:10 [INFO] Parsed rounds to Pandas DataFrame
# 18:05:10 [INFO] Parsed damages to Pandas DataFrame
# 18:05:10 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:05:10 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-pain-m1-nuke.dem
# 18:05:33 [INFO] Wrote demo parse output to furia-vs-pain-m1-nuke.json
# 18:05:33 [INFO] Reading in JSON from furia-vs-pain-m1-nuke.json
# 18:05:34 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:05:34 [INFO] Successfully parsed JSON output
# 18:05:34 [INFO] Successfully returned JSON output
# 18:05:34 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:05:34 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-pain-m1-nuke.dem
# 18:05:56 [INFO] Wrote demo parse output to furia-vs-pain-m1-nuke.json
# 18:05:56 [INFO] Reading in JSON from furia-vs-pain-m1-nuke.json
# 18:05:57 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:05:57 [INFO] Successfully parsed JSON output
# 18:05:57 [INFO] Successfully returned JSON output
# 18:05:57 [INFO] Parsed rounds to Pandas DataFrame
# 18:05:57 [INFO] Parsed kills to Pandas DataFrame
# 18:05:57 [INFO] Parsed damages to Pandas DataFrame
# 18:05:57 [INFO] Parsed grenades to Pandas DataFrame
# 18:05:57 [INFO] Parsed flashes to Pandas DataFrame
# 18:05:57 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:05:57 [INFO] Parsed frames to Pandas DataFrame
# 18:05:57 [INFO] Parsed player frames to Pandas DataFrame
# 18:05:57 [INFO] Returned dataframe output
# 18:05:57 [INFO] Parsed kills to Pandas DataFrame
# 18:05:57 [INFO] Parsed grenades to Pandas DataFrame
# 18:05:57 [INFO] Parsed flashes to Pandas DataFrame
# 18:05:57 [INFO] Parsed rounds to Pandas DataFrame
# 18:05:57 [INFO] Parsed damages to Pandas DataFrame
# 18:05:57 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:05:57 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-pain-m2-mirage.dem
# 18:06:21 [INFO] Wrote demo parse output to furia-vs-pain-m2-mirage.json
# 18:06:21 [INFO] Reading in JSON from furia-vs-pain-m2-mirage.json
# 18:06:21 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:06:21 [INFO] Successfully parsed JSON output
# 18:06:21 [INFO] Successfully returned JSON output
# 18:06:21 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:06:21 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/furia-vs-pain-m2-mirage.dem
# 18:06:45 [INFO] Wrote demo parse output to furia-vs-pain-m2-mirage.json
# 18:06:45 [INFO] Reading in JSON from furia-vs-pain-m2-mirage.json
# 18:06:45 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:06:45 [INFO] Successfully parsed JSON output
# 18:06:45 [INFO] Successfully returned JSON output
# 18:06:45 [INFO] Parsed rounds to Pandas DataFrame
# 18:06:45 [INFO] Parsed kills to Pandas DataFrame
# 18:06:45 [INFO] Parsed damages to Pandas DataFrame
# 18:06:45 [INFO] Parsed grenades to Pandas DataFrame
# 18:06:45 [INFO] Parsed flashes to Pandas DataFrame
# 18:06:45 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:06:45 [INFO] Parsed frames to Pandas DataFrame
# 18:06:45 [INFO] Parsed player frames to Pandas DataFrame
# 18:06:45 [INFO] Returned dataframe output
# 18:06:45 [INFO] Parsed kills to Pandas DataFrame
# 18:06:45 [INFO] Parsed grenades to Pandas DataFrame
# 18:06:45 [INFO] Parsed flashes to Pandas DataFrame
# 18:06:46 [INFO] Parsed rounds to Pandas DataFrame
# 18:06:46 [INFO] Parsed damages to Pandas DataFrame
# 18:06:46 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:06:46 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-astralis-m1-train.dem
# 18:06:59 [INFO] Wrote demo parse output to g2-vs-astralis-m1-train.json
# 18:06:59 [INFO] Reading in JSON from g2-vs-astralis-m1-train.json
# 18:07:00 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:07:00 [INFO] Successfully parsed JSON output
# 18:07:00 [INFO] Successfully returned JSON output
# 18:07:00 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:07:00 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-astralis-m1-train.dem
# 18:07:13 [INFO] Wrote demo parse output to g2-vs-astralis-m1-train.json
# 18:07:13 [INFO] Reading in JSON from g2-vs-astralis-m1-train.json
# 18:07:14 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:07:14 [INFO] Successfully parsed JSON output
# 18:07:14 [INFO] Successfully returned JSON output
# 18:07:14 [INFO] Parsed rounds to Pandas DataFrame
# 18:07:14 [INFO] Parsed kills to Pandas DataFrame
# 18:07:14 [INFO] Parsed damages to Pandas DataFrame
# 18:07:14 [INFO] Parsed grenades to Pandas DataFrame
# 18:07:14 [INFO] Parsed flashes to Pandas DataFrame
# 18:07:14 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:07:14 [INFO] Parsed frames to Pandas DataFrame
# 18:07:14 [INFO] Parsed player frames to Pandas DataFrame
# 18:07:14 [INFO] Returned dataframe output
# 18:07:14 [INFO] Parsed kills to Pandas DataFrame
# 18:07:14 [INFO] Parsed grenades to Pandas DataFrame
# 18:07:14 [INFO] Parsed flashes to Pandas DataFrame
# 18:07:14 [INFO] Parsed rounds to Pandas DataFrame
# 18:07:14 [INFO] Parsed damages to Pandas DataFrame
# 18:07:14 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:07:14 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-astralis-m3-vertigo.dem
# 18:07:29 [INFO] Wrote demo parse output to g2-vs-astralis-m3-vertigo.json
# 18:07:29 [INFO] Reading in JSON from g2-vs-astralis-m3-vertigo.json
# 18:07:29 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:07:29 [INFO] Successfully parsed JSON output
# 18:07:29 [INFO] Successfully returned JSON output
# 18:07:29 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:07:29 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-astralis-m3-vertigo.dem
# 18:07:44 [INFO] Wrote demo parse output to g2-vs-astralis-m3-vertigo.json
# 18:07:44 [INFO] Reading in JSON from g2-vs-astralis-m3-vertigo.json
# 18:07:44 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:07:44 [INFO] Successfully parsed JSON output
# 18:07:44 [INFO] Successfully returned JSON output
# 18:07:44 [INFO] Parsed rounds to Pandas DataFrame
# 18:07:44 [INFO] Parsed kills to Pandas DataFrame
# 18:07:44 [INFO] Parsed damages to Pandas DataFrame
# 18:07:44 [INFO] Parsed grenades to Pandas DataFrame
# 18:07:44 [INFO] Parsed flashes to Pandas DataFrame
# 18:07:44 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:07:44 [INFO] Parsed frames to Pandas DataFrame
# 18:07:44 [INFO] Parsed player frames to Pandas DataFrame
# 18:07:44 [INFO] Returned dataframe output
# 18:07:44 [INFO] Parsed kills to Pandas DataFrame
# 18:07:44 [INFO] Parsed grenades to Pandas DataFrame
# 18:07:44 [INFO] Parsed flashes to Pandas DataFrame
# 18:07:44 [INFO] Parsed rounds to Pandas DataFrame
# 18:07:44 [INFO] Parsed damages to Pandas DataFrame
# 18:07:44 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:07:44 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-mousesports-m1-vertigo_1.dem
# 18:08:01 [INFO] Wrote demo parse output to g2-vs-mousesports-m1-vertigo.json
# 18:08:01 [INFO] Reading in JSON from g2-vs-mousesports-m1-vertigo.json
# 18:08:02 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:08:02 [INFO] Successfully parsed JSON output
# 18:08:02 [INFO] Successfully returned JSON output
# 18:08:02 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:08:02 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/g2-vs-mousesports-m1-vertigo_1.dem
# 18:08:19 [INFO] Wrote demo parse output to g2-vs-mousesports-m1-vertigo.json
# 18:08:19 [INFO] Reading in JSON from g2-vs-mousesports-m1-vertigo.json
# 18:08:19 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:08:19 [INFO] Successfully parsed JSON output
# 18:08:19 [INFO] Successfully returned JSON output
# 18:08:19 [INFO] Parsed rounds to Pandas DataFrame
# 18:08:19 [INFO] Parsed kills to Pandas DataFrame
# 18:08:19 [INFO] Parsed damages to Pandas DataFrame
# 18:08:19 [INFO] Parsed grenades to Pandas DataFrame
# 18:08:19 [INFO] Parsed flashes to Pandas DataFrame
# 18:08:19 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:08:19 [INFO] Parsed frames to Pandas DataFrame
# 18:08:19 [INFO] Parsed player frames to Pandas DataFrame
# 18:08:19 [INFO] Returned dataframe output
# 18:08:19 [INFO] Parsed kills to Pandas DataFrame
# 18:08:19 [INFO] Parsed grenades to Pandas DataFrame
# 18:08:19 [INFO] Parsed flashes to Pandas DataFrame
# 18:08:19 [INFO] Parsed rounds to Pandas DataFrame
# 18:08:19 [INFO] Parsed damages to Pandas DataFrame
# 18:08:19 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:08:19 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-fiend-dust2.dem
# 18:08:33 [INFO] Wrote demo parse output to gambit-vs-fiend-dust2.json
# 18:08:33 [INFO] Reading in JSON from gambit-vs-fiend-dust2.json
# 18:08:33 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:08:33 [INFO] Successfully parsed JSON output
# 18:08:33 [INFO] Successfully returned JSON output
# 18:08:33 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:08:33 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-fiend-dust2.dem
# 18:08:46 [INFO] Wrote demo parse output to gambit-vs-fiend-dust2.json
# 18:08:46 [INFO] Reading in JSON from gambit-vs-fiend-dust2.json
# 18:08:46 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:08:46 [INFO] Successfully parsed JSON output
# 18:08:46 [INFO] Successfully returned JSON output
# 18:08:46 [INFO] Parsed rounds to Pandas DataFrame
# 18:08:46 [INFO] Parsed kills to Pandas DataFrame
# 18:08:46 [INFO] Parsed damages to Pandas DataFrame
# 18:08:46 [INFO] Parsed grenades to Pandas DataFrame
# 18:08:46 [INFO] Parsed flashes to Pandas DataFrame
# 18:08:47 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:08:47 [INFO] Parsed frames to Pandas DataFrame
# 18:08:47 [INFO] Parsed player frames to Pandas DataFrame
# 18:08:47 [INFO] Returned dataframe output
# 18:08:47 [INFO] Parsed kills to Pandas DataFrame
# 18:08:47 [INFO] Parsed grenades to Pandas DataFrame
# 18:08:47 [INFO] Parsed flashes to Pandas DataFrame
# 18:08:47 [INFO] Parsed rounds to Pandas DataFrame
# 18:08:47 [INFO] Parsed damages to Pandas DataFrame
# 18:08:47 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:08:47 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m1-inferno.dem
# 18:09:02 [INFO] Wrote demo parse output to gambit-vs-g2-m1-inferno.json
# 18:09:02 [INFO] Reading in JSON from gambit-vs-g2-m1-inferno.json
# 18:09:03 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:09:03 [INFO] Successfully parsed JSON output
# 18:09:03 [INFO] Successfully returned JSON output
# 18:09:03 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:09:03 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m1-inferno.dem
# 18:09:18 [INFO] Wrote demo parse output to gambit-vs-g2-m1-inferno.json
# 18:09:18 [INFO] Reading in JSON from gambit-vs-g2-m1-inferno.json
# 18:09:19 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:09:19 [INFO] Successfully parsed JSON output
# 18:09:19 [INFO] Successfully returned JSON output
# 18:09:19 [INFO] Parsed rounds to Pandas DataFrame
# 18:09:19 [INFO] Parsed kills to Pandas DataFrame
# 18:09:19 [INFO] Parsed damages to Pandas DataFrame
# 18:09:20 [INFO] Parsed grenades to Pandas DataFrame
# 18:09:20 [INFO] Parsed flashes to Pandas DataFrame
# 18:09:20 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:09:20 [INFO] Parsed frames to Pandas DataFrame
# 18:09:20 [INFO] Parsed player frames to Pandas DataFrame
# 18:09:20 [INFO] Returned dataframe output
# 18:09:20 [INFO] Parsed kills to Pandas DataFrame
# 18:09:20 [INFO] Parsed grenades to Pandas DataFrame
# 18:09:20 [INFO] Parsed flashes to Pandas DataFrame
# 18:09:20 [INFO] Parsed rounds to Pandas DataFrame
# 18:09:20 [INFO] Parsed damages to Pandas DataFrame
# 18:09:20 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:09:20 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m2-train.dem
# 18:09:35 [INFO] Wrote demo parse output to gambit-vs-g2-m2-train.json
# 18:09:35 [INFO] Reading in JSON from gambit-vs-g2-m2-train.json
# 18:09:36 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:09:36 [INFO] Successfully parsed JSON output
# 18:09:36 [INFO] Successfully returned JSON output
# 18:09:36 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:09:36 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m2-train.dem
# 18:09:51 [INFO] Wrote demo parse output to gambit-vs-g2-m2-train.json
# 18:09:51 [INFO] Reading in JSON from gambit-vs-g2-m2-train.json
# 18:09:52 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:09:52 [INFO] Successfully parsed JSON output
# 18:09:52 [INFO] Successfully returned JSON output
# 18:09:52 [INFO] Parsed rounds to Pandas DataFrame
# 18:09:52 [INFO] Parsed kills to Pandas DataFrame
# 18:09:52 [INFO] Parsed damages to Pandas DataFrame
# 18:09:52 [INFO] Parsed grenades to Pandas DataFrame
# 18:09:52 [INFO] Parsed flashes to Pandas DataFrame
# 18:09:52 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:09:52 [INFO] Parsed frames to Pandas DataFrame
# 18:09:52 [INFO] Parsed player frames to Pandas DataFrame
# 18:09:52 [INFO] Returned dataframe output
# 18:09:52 [INFO] Parsed kills to Pandas DataFrame
# 18:09:52 [INFO] Parsed grenades to Pandas DataFrame
# 18:09:52 [INFO] Parsed flashes to Pandas DataFrame
# 18:09:52 [INFO] Parsed rounds to Pandas DataFrame
# 18:09:52 [INFO] Parsed damages to Pandas DataFrame
# 18:09:52 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:09:52 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m2-vertigo.dem
# 18:10:07 [INFO] Wrote demo parse output to gambit-vs-g2-m2-vertigo.json
# 18:10:07 [INFO] Reading in JSON from gambit-vs-g2-m2-vertigo.json
# 18:10:08 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:10:08 [INFO] Successfully parsed JSON output
# 18:10:08 [INFO] Successfully returned JSON output
# 18:10:08 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:10:08 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m2-vertigo.dem
# 18:10:23 [INFO] Wrote demo parse output to gambit-vs-g2-m2-vertigo.json
# 18:10:23 [INFO] Reading in JSON from gambit-vs-g2-m2-vertigo.json
# 18:10:23 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:10:23 [INFO] Successfully parsed JSON output
# 18:10:23 [INFO] Successfully returned JSON output
# 18:10:23 [INFO] Parsed rounds to Pandas DataFrame
# 18:10:23 [INFO] Parsed kills to Pandas DataFrame
# 18:10:23 [INFO] Parsed damages to Pandas DataFrame
# 18:10:23 [INFO] Parsed grenades to Pandas DataFrame
# 18:10:23 [INFO] Parsed flashes to Pandas DataFrame
# 18:10:23 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:10:23 [INFO] Parsed frames to Pandas DataFrame
# 18:10:23 [INFO] Parsed player frames to Pandas DataFrame
# 18:10:23 [INFO] Returned dataframe output
# 18:10:23 [INFO] Parsed kills to Pandas DataFrame
# 18:10:23 [INFO] Parsed grenades to Pandas DataFrame
# 18:10:23 [INFO] Parsed flashes to Pandas DataFrame
# 18:10:23 [INFO] Parsed rounds to Pandas DataFrame
# 18:10:23 [INFO] Parsed damages to Pandas DataFrame
# 18:10:24 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:10:24 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m3-dust2.dem
# 18:10:35 [INFO] Wrote demo parse output to gambit-vs-g2-m3-dust2.json
# 18:10:35 [INFO] Reading in JSON from gambit-vs-g2-m3-dust2.json
# 18:10:35 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:10:35 [INFO] Successfully parsed JSON output
# 18:10:35 [INFO] Successfully returned JSON output
# 18:10:35 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:10:35 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-g2-m3-dust2.dem
# 18:10:46 [INFO] Wrote demo parse output to gambit-vs-g2-m3-dust2.json
# 18:10:46 [INFO] Reading in JSON from gambit-vs-g2-m3-dust2.json
# 18:10:47 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:10:47 [INFO] Successfully parsed JSON output
# 18:10:47 [INFO] Successfully returned JSON output
# 18:10:47 [INFO] Parsed rounds to Pandas DataFrame
# 18:10:47 [INFO] Parsed kills to Pandas DataFrame
# 18:10:47 [INFO] Parsed damages to Pandas DataFrame
# 18:10:47 [INFO] Parsed grenades to Pandas DataFrame
# 18:10:47 [INFO] Parsed flashes to Pandas DataFrame
# 18:10:47 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:10:47 [INFO] Parsed frames to Pandas DataFrame
# 18:10:47 [INFO] Parsed player frames to Pandas DataFrame
# 18:10:47 [INFO] Returned dataframe output
# 18:10:47 [INFO] Parsed kills to Pandas DataFrame
# 18:10:47 [INFO] Parsed grenades to Pandas DataFrame
# 18:10:47 [INFO] Parsed flashes to Pandas DataFrame
# 18:10:47 [INFO] Parsed rounds to Pandas DataFrame
# 18:10:47 [INFO] Parsed damages to Pandas DataFrame
# 18:10:47 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:10:47 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-natus-vincere-m2-overpass.dem
# 18:11:06 [INFO] Wrote demo parse output to gambit-vs-natus-vincere-m2-overpass.json
# 18:11:06 [INFO] Reading in JSON from gambit-vs-natus-vincere-m2-overpass.json
# 18:11:06 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:11:06 [INFO] Successfully parsed JSON output
# 18:11:06 [INFO] Successfully returned JSON output
# 18:11:06 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:11:06 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-natus-vincere-m2-overpass.dem
# 18:11:25 [INFO] Wrote demo parse output to gambit-vs-natus-vincere-m2-overpass.json
# 18:11:25 [INFO] Reading in JSON from gambit-vs-natus-vincere-m2-overpass.json
# 18:11:25 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:11:25 [INFO] Successfully parsed JSON output
# 18:11:25 [INFO] Successfully returned JSON output
# 18:11:25 [INFO] Parsed rounds to Pandas DataFrame
# 18:11:25 [INFO] Parsed kills to Pandas DataFrame
# 18:11:25 [INFO] Parsed damages to Pandas DataFrame
# 18:11:25 [INFO] Parsed grenades to Pandas DataFrame
# 18:11:25 [INFO] Parsed flashes to Pandas DataFrame
# 18:11:25 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:11:25 [INFO] Parsed frames to Pandas DataFrame
# 18:11:25 [INFO] Parsed player frames to Pandas DataFrame
# 18:11:25 [INFO] Returned dataframe output
# 18:11:25 [INFO] Parsed kills to Pandas DataFrame
# 18:11:25 [INFO] Parsed grenades to Pandas DataFrame
# 18:11:25 [INFO] Parsed flashes to Pandas DataFrame
# 18:11:25 [INFO] Parsed rounds to Pandas DataFrame
# 18:11:25 [INFO] Parsed damages to Pandas DataFrame
# 18:11:25 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:11:25 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-natus-vincere-m3-mirage.dem
# 18:11:48 [INFO] Wrote demo parse output to gambit-vs-natus-vincere-m3-mirage.json
# 18:11:48 [INFO] Reading in JSON from gambit-vs-natus-vincere-m3-mirage.json
# 18:11:49 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:11:49 [INFO] Successfully parsed JSON output
# 18:11:49 [INFO] Successfully returned JSON output
# 18:11:49 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:11:49 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/gambit-vs-natus-vincere-m3-mirage.dem
# 18:12:12 [INFO] Wrote demo parse output to gambit-vs-natus-vincere-m3-mirage.json
# 18:12:12 [INFO] Reading in JSON from gambit-vs-natus-vincere-m3-mirage.json
# 18:12:13 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:12:13 [INFO] Successfully parsed JSON output
# 18:12:13 [INFO] Successfully returned JSON output
# 18:12:13 [INFO] Parsed rounds to Pandas DataFrame
# 18:12:13 [INFO] Parsed kills to Pandas DataFrame
# 18:12:13 [INFO] Parsed damages to Pandas DataFrame
# 18:12:13 [INFO] Parsed grenades to Pandas DataFrame
# 18:12:13 [INFO] Parsed flashes to Pandas DataFrame
# 18:12:13 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:12:13 [INFO] Parsed frames to Pandas DataFrame
# 18:12:13 [INFO] Parsed player frames to Pandas DataFrame
# 18:12:13 [INFO] Returned dataframe output
# 18:12:13 [INFO] Parsed kills to Pandas DataFrame
# 18:12:13 [INFO] Parsed grenades to Pandas DataFrame
# 18:12:13 [INFO] Parsed flashes to Pandas DataFrame
# 18:12:13 [INFO] Parsed rounds to Pandas DataFrame
# 18:12:13 [INFO] Parsed damages to Pandas DataFrame
# 18:12:13 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:12:13 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m1-mirage.dem
# 18:12:35 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m1-mirage.json
# 18:12:35 [INFO] Reading in JSON from heroic-vs-natus-vincere-m1-mirage.json
# 18:12:36 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:12:36 [INFO] Successfully parsed JSON output
# 18:12:36 [INFO] Successfully returned JSON output
# 18:12:36 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:12:36 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m1-mirage.dem
# 18:12:58 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m1-mirage.json
# 18:12:58 [INFO] Reading in JSON from heroic-vs-natus-vincere-m1-mirage.json
# 18:12:59 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:12:59 [INFO] Successfully parsed JSON output
# 18:12:59 [INFO] Successfully returned JSON output
# 18:12:59 [INFO] Parsed rounds to Pandas DataFrame
# 18:12:59 [INFO] Parsed kills to Pandas DataFrame
# 18:12:59 [INFO] Parsed damages to Pandas DataFrame
# 18:12:59 [INFO] Parsed grenades to Pandas DataFrame
# 18:12:59 [INFO] Parsed flashes to Pandas DataFrame
# 18:12:59 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:12:59 [INFO] Parsed frames to Pandas DataFrame
# 18:12:59 [INFO] Parsed player frames to Pandas DataFrame
# 18:12:59 [INFO] Returned dataframe output
# 18:12:59 [INFO] Parsed kills to Pandas DataFrame
# 18:12:59 [INFO] Parsed grenades to Pandas DataFrame
# 18:12:59 [INFO] Parsed flashes to Pandas DataFrame
# 18:12:59 [INFO] Parsed rounds to Pandas DataFrame
# 18:12:59 [INFO] Parsed damages to Pandas DataFrame
# 18:12:59 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:12:59 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m2-nuke.dem
# 18:13:21 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m2-nuke.json
# 18:13:21 [INFO] Reading in JSON from heroic-vs-natus-vincere-m2-nuke.json
# 18:13:22 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:13:22 [INFO] Successfully parsed JSON output
# 18:13:22 [INFO] Successfully returned JSON output
# 18:13:22 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:13:22 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m2-nuke.dem
# 18:13:44 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m2-nuke.json
# 18:13:44 [INFO] Reading in JSON from heroic-vs-natus-vincere-m2-nuke.json
# 18:13:45 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:13:45 [INFO] Successfully parsed JSON output
# 18:13:45 [INFO] Successfully returned JSON output
# 18:13:45 [INFO] Parsed rounds to Pandas DataFrame
# 18:13:45 [INFO] Parsed kills to Pandas DataFrame
# 18:13:45 [INFO] Parsed damages to Pandas DataFrame
# 18:13:45 [INFO] Parsed grenades to Pandas DataFrame
# 18:13:45 [INFO] Parsed flashes to Pandas DataFrame
# 18:13:45 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:13:45 [INFO] Parsed frames to Pandas DataFrame
# 18:13:45 [INFO] Parsed player frames to Pandas DataFrame
# 18:13:45 [INFO] Returned dataframe output
# 18:13:45 [INFO] Parsed kills to Pandas DataFrame
# 18:13:45 [INFO] Parsed grenades to Pandas DataFrame
# 18:13:45 [INFO] Parsed flashes to Pandas DataFrame
# 18:13:45 [INFO] Parsed rounds to Pandas DataFrame
# 18:13:45 [INFO] Parsed damages to Pandas DataFrame
# 18:13:45 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:13:45 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m2-nuke_1.dem
# 18:14:07 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m2-nuke.json
# 18:14:07 [INFO] Reading in JSON from heroic-vs-natus-vincere-m2-nuke.json
# 18:14:07 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:14:07 [INFO] Successfully parsed JSON output
# 18:14:07 [INFO] Successfully returned JSON output
# 18:14:07 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:14:07 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m2-nuke_1.dem
# 18:14:29 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m2-nuke.json
# 18:14:29 [INFO] Reading in JSON from heroic-vs-natus-vincere-m2-nuke.json
# 18:14:30 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:14:30 [INFO] Successfully parsed JSON output
# 18:14:30 [INFO] Successfully returned JSON output
# 18:14:30 [INFO] Parsed rounds to Pandas DataFrame
# 18:14:30 [INFO] Parsed kills to Pandas DataFrame
# 18:14:30 [INFO] Parsed damages to Pandas DataFrame
# 18:14:30 [INFO] Parsed grenades to Pandas DataFrame
# 18:14:30 [INFO] Parsed flashes to Pandas DataFrame
# 18:14:30 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:14:30 [INFO] Parsed frames to Pandas DataFrame
# 18:14:30 [INFO] Parsed player frames to Pandas DataFrame
# 18:14:30 [INFO] Returned dataframe output
# 18:14:30 [INFO] Parsed kills to Pandas DataFrame
# 18:14:30 [INFO] Parsed grenades to Pandas DataFrame
# 18:14:30 [INFO] Parsed flashes to Pandas DataFrame
# 18:14:30 [INFO] Parsed rounds to Pandas DataFrame
# 18:14:30 [INFO] Parsed damages to Pandas DataFrame
# 18:14:30 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:14:30 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m3-inferno.dem
# 18:14:48 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m3-inferno.json
# 18:14:48 [INFO] Reading in JSON from heroic-vs-natus-vincere-m3-inferno.json
# 18:14:49 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:14:49 [INFO] Successfully parsed JSON output
# 18:14:49 [INFO] Successfully returned JSON output
# 18:14:49 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:14:49 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m3-inferno.dem
# 18:15:07 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m3-inferno.json
# 18:15:07 [INFO] Reading in JSON from heroic-vs-natus-vincere-m3-inferno.json
# 18:15:08 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:15:08 [INFO] Successfully parsed JSON output
# 18:15:08 [INFO] Successfully returned JSON output
# 18:15:08 [INFO] Parsed rounds to Pandas DataFrame
# 18:15:08 [INFO] Parsed kills to Pandas DataFrame
# 18:15:08 [INFO] Parsed damages to Pandas DataFrame
# 18:15:08 [INFO] Parsed grenades to Pandas DataFrame
# 18:15:08 [INFO] Parsed flashes to Pandas DataFrame
# 18:15:08 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:15:08 [INFO] Parsed frames to Pandas DataFrame
# 18:15:08 [INFO] Parsed player frames to Pandas DataFrame
# 18:15:08 [INFO] Returned dataframe output
# 18:15:08 [INFO] Parsed kills to Pandas DataFrame
# 18:15:08 [INFO] Parsed grenades to Pandas DataFrame
# 18:15:08 [INFO] Parsed flashes to Pandas DataFrame
# 18:15:08 [INFO] Parsed rounds to Pandas DataFrame
# 18:15:08 [INFO] Parsed damages to Pandas DataFrame
# 18:15:08 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:15:08 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m3-inferno_1.dem
# 18:15:27 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m3-inferno.json
# 18:15:27 [INFO] Reading in JSON from heroic-vs-natus-vincere-m3-inferno.json
# 18:15:28 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:15:28 [INFO] Successfully parsed JSON output
# 18:15:28 [INFO] Successfully returned JSON output
# 18:15:28 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:15:28 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/heroic-vs-natus-vincere-m3-inferno_1.dem
# 18:15:46 [INFO] Wrote demo parse output to heroic-vs-natus-vincere-m3-inferno.json
# 18:15:46 [INFO] Reading in JSON from heroic-vs-natus-vincere-m3-inferno.json
# 18:15:47 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:15:47 [INFO] Successfully parsed JSON output
# 18:15:47 [INFO] Successfully returned JSON output
# 18:15:47 [INFO] Parsed rounds to Pandas DataFrame
# 18:15:47 [INFO] Parsed kills to Pandas DataFrame
# 18:15:47 [INFO] Parsed damages to Pandas DataFrame
# 18:15:47 [INFO] Parsed grenades to Pandas DataFrame
# 18:15:47 [INFO] Parsed flashes to Pandas DataFrame
# 18:15:47 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:15:47 [INFO] Parsed frames to Pandas DataFrame
# 18:15:47 [INFO] Parsed player frames to Pandas DataFrame
# 18:15:47 [INFO] Returned dataframe output
# 18:15:47 [INFO] Parsed kills to Pandas DataFrame
# 18:15:47 [INFO] Parsed grenades to Pandas DataFrame
# 18:15:47 [INFO] Parsed flashes to Pandas DataFrame
# 18:15:47 [INFO] Parsed rounds to Pandas DataFrame
# 18:15:47 [INFO] Parsed damages to Pandas DataFrame
# 18:15:47 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:15:47 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/mousesports-vs-faze-m1-mirage.dem
# 18:16:07 [INFO] Wrote demo parse output to mousesports-vs-faze-m1-mirage.json
# 18:16:07 [INFO] Reading in JSON from mousesports-vs-faze-m1-mirage.json
# 18:16:07 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:16:07 [INFO] Successfully parsed JSON output
# 18:16:07 [INFO] Successfully returned JSON output
# 18:16:07 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:16:07 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/mousesports-vs-faze-m1-mirage.dem
# 18:16:27 [INFO] Wrote demo parse output to mousesports-vs-faze-m1-mirage.json
# ...
# 18:20:56 [INFO] Parsed frames to Pandas DataFrame
# 18:20:56 [INFO] Parsed player frames to Pandas DataFrame
# 18:20:56 [INFO] Returned dataframe output
# 18:20:56 [INFO] Parsed kills to Pandas DataFrame
# 18:20:56 [INFO] Parsed grenades to Pandas DataFrame
# 18:20:56 [INFO] Parsed flashes to Pandas DataFrame
# 18:20:56 [INFO] Parsed rounds to Pandas DataFrame
# 18:20:56 [INFO] Parsed damages to Pandas DataFrame
# 18:20:57 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:20:57 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/pain-vs-heroic-nuke.dem
# 18:21:15 [INFO] Wrote demo parse output to pain-vs-heroic-nuke.json
# 18:21:15 [INFO] Reading in JSON from pain-vs-heroic-nuke.json
# 18:21:15 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:21:15 [INFO] Successfully parsed JSON output
# 18:21:15 [INFO] Successfully returned JSON output
# 18:21:15 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:21:15 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/pain-vs-heroic-nuke.dem
# 18:21:34 [INFO] Wrote demo parse output to pain-vs-heroic-nuke.json
# 18:21:34 [INFO] Reading in JSON from pain-vs-heroic-nuke.json
# 18:21:35 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:21:35 [INFO] Successfully parsed JSON output
# 18:21:35 [INFO] Successfully returned JSON output
# 18:21:35 [INFO] Parsed rounds to Pandas DataFrame
# 18:21:35 [INFO] Parsed kills to Pandas DataFrame
# 18:21:35 [INFO] Parsed damages to Pandas DataFrame
# 18:21:35 [INFO] Parsed grenades to Pandas DataFrame
# 18:21:35 [INFO] Parsed flashes to Pandas DataFrame
# 18:21:35 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:21:35 [INFO] Parsed frames to Pandas DataFrame
# 18:21:35 [INFO] Parsed player frames to Pandas DataFrame
# 18:21:35 [INFO] Returned dataframe output
# 18:21:35 [INFO] Parsed kills to Pandas DataFrame
# 18:21:35 [INFO] Parsed grenades to Pandas DataFrame
# 18:21:35 [INFO] Parsed flashes to Pandas DataFrame
# 18:21:35 [INFO] Parsed rounds to Pandas DataFrame
# 18:21:35 [INFO] Parsed damages to Pandas DataFrame
# 18:21:35 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:21:35 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/spirit-vs-g2-mirage.dem
# 18:22:07 [INFO] Wrote demo parse output to spirit-vs-g2-mirage.json
# 18:22:07 [INFO] Reading in JSON from spirit-vs-g2-mirage.json
# 18:22:07 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:22:07 [INFO] Successfully parsed JSON output
# 18:22:07 [INFO] Successfully returned JSON output
# 18:22:07 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:22:07 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/spirit-vs-g2-mirage.dem
# 18:22:38 [INFO] Wrote demo parse output to spirit-vs-g2-mirage.json
# 18:22:38 [INFO] Reading in JSON from spirit-vs-g2-mirage.json
# 18:22:39 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:22:39 [INFO] Successfully parsed JSON output
# 18:22:39 [INFO] Successfully returned JSON output
# 18:22:39 [INFO] Parsed rounds to Pandas DataFrame
# 18:22:39 [INFO] Parsed kills to Pandas DataFrame
# 18:22:39 [INFO] Parsed damages to Pandas DataFrame
# 18:22:39 [INFO] Parsed grenades to Pandas DataFrame
# 18:22:39 [INFO] Parsed flashes to Pandas DataFrame
# 18:22:39 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:22:39 [INFO] Parsed frames to Pandas DataFrame
# 18:22:39 [INFO] Parsed player frames to Pandas DataFrame
# 18:22:39 [INFO] Returned dataframe output
# 18:22:39 [INFO] Parsed kills to Pandas DataFrame
# 18:22:39 [INFO] Parsed grenades to Pandas DataFrame
# 18:22:39 [INFO] Parsed flashes to Pandas DataFrame
# 18:22:39 [INFO] Parsed rounds to Pandas DataFrame
# 18:22:39 [INFO] Parsed damages to Pandas DataFrame
# 18:22:39 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:22:39 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/spirit-vs-virtus-pro-m2-inferno.dem
# 18:22:57 [INFO] Wrote demo parse output to spirit-vs-virtus-pro-m2-inferno.json
# 18:22:57 [INFO] Reading in JSON from spirit-vs-virtus-pro-m2-inferno.json
# 18:22:58 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:22:58 [INFO] Successfully parsed JSON output
# 18:22:58 [INFO] Successfully returned JSON output
# 18:22:58 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:22:58 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/spirit-vs-virtus-pro-m2-inferno.dem
# 18:23:16 [INFO] Wrote demo parse output to spirit-vs-virtus-pro-m2-inferno.json
# 18:23:16 [INFO] Reading in JSON from spirit-vs-virtus-pro-m2-inferno.json
# 18:23:16 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:23:16 [INFO] Successfully parsed JSON output
# 18:23:16 [INFO] Successfully returned JSON output
# 18:23:16 [INFO] Parsed rounds to Pandas DataFrame
# 18:23:16 [INFO] Parsed kills to Pandas DataFrame
# 18:23:16 [INFO] Parsed damages to Pandas DataFrame
# 18:23:16 [INFO] Parsed grenades to Pandas DataFrame
# 18:23:16 [INFO] Parsed flashes to Pandas DataFrame
# 18:23:16 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:23:16 [INFO] Parsed frames to Pandas DataFrame
# 18:23:16 [INFO] Parsed player frames to Pandas DataFrame
# 18:23:16 [INFO] Returned dataframe output
# 18:23:16 [INFO] Parsed kills to Pandas DataFrame
# 18:23:16 [INFO] Parsed grenades to Pandas DataFrame
# 18:23:16 [INFO] Parsed flashes to Pandas DataFrame
# 18:23:16 [INFO] Parsed rounds to Pandas DataFrame
# 18:23:16 [INFO] Parsed damages to Pandas DataFrame
# 18:23:16 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:23:16 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/virtus-pro-vs-g2-m1-vertigo.dem
# 18:23:33 [INFO] Wrote demo parse output to virtus-pro-vs-g2-m1-vertigo.json
# 18:23:33 [INFO] Reading in JSON from virtus-pro-vs-g2-m1-vertigo.json
# 18:23:34 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:23:34 [INFO] Successfully parsed JSON output
# 18:23:34 [INFO] Successfully returned JSON output
# 18:23:34 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:23:34 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/virtus-pro-vs-g2-m1-vertigo.dem
# 18:23:51 [INFO] Wrote demo parse output to virtus-pro-vs-g2-m1-vertigo.json
# 18:23:51 [INFO] Reading in JSON from virtus-pro-vs-g2-m1-vertigo.json
# 18:23:51 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:23:51 [INFO] Successfully parsed JSON output
# 18:23:51 [INFO] Successfully returned JSON output
# 18:23:51 [INFO] Parsed rounds to Pandas DataFrame
# 18:23:51 [INFO] Parsed kills to Pandas DataFrame
# 18:23:51 [INFO] Parsed damages to Pandas DataFrame
# 18:23:51 [INFO] Parsed grenades to Pandas DataFrame
# 18:23:51 [INFO] Parsed flashes to Pandas DataFrame
# 18:23:51 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:23:51 [INFO] Parsed frames to Pandas DataFrame
# 18:23:52 [INFO] Parsed player frames to Pandas DataFrame
# 18:23:52 [INFO] Returned dataframe output
# 18:23:52 [INFO] Parsed kills to Pandas DataFrame
# 18:23:52 [INFO] Parsed grenades to Pandas DataFrame
# 18:23:52 [INFO] Parsed flashes to Pandas DataFrame
# 18:23:52 [INFO] Parsed rounds to Pandas DataFrame
# 18:23:52 [INFO] Parsed damages to Pandas DataFrame
# 18:23:52 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:23:52 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/virtus-pro-vs-g2-m2-inferno.dem
# 18:24:08 [INFO] Wrote demo parse output to virtus-pro-vs-g2-m2-inferno.json
# 18:24:08 [INFO] Reading in JSON from virtus-pro-vs-g2-m2-inferno.json
# 18:24:08 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:24:08 [INFO] Successfully parsed JSON output
# 18:24:08 [INFO] Successfully returned JSON output
# 18:24:08 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:24:08 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/virtus-pro-vs-g2-m2-inferno.dem
# 18:24:24 [INFO] Wrote demo parse output to virtus-pro-vs-g2-m2-inferno.json
# 18:24:24 [INFO] Reading in JSON from virtus-pro-vs-g2-m2-inferno.json
# 18:24:26 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:24:26 [INFO] Successfully parsed JSON output
# 18:24:26 [INFO] Successfully returned JSON output
# 18:24:26 [INFO] Parsed rounds to Pandas DataFrame
# 18:24:26 [INFO] Parsed kills to Pandas DataFrame
# 18:24:26 [INFO] Parsed damages to Pandas DataFrame
# 18:24:26 [INFO] Parsed grenades to Pandas DataFrame
# 18:24:26 [INFO] Parsed flashes to Pandas DataFrame
# 18:24:26 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:24:26 [INFO] Parsed frames to Pandas DataFrame
# 18:24:26 [INFO] Parsed player frames to Pandas DataFrame
# 18:24:26 [INFO] Returned dataframe output
# 18:24:26 [INFO] Parsed kills to Pandas DataFrame
# 18:24:26 [INFO] Parsed grenades to Pandas DataFrame
# 18:24:26 [INFO] Parsed flashes to Pandas DataFrame
# 18:24:26 [INFO] Parsed rounds to Pandas DataFrame
# 18:24:26 [INFO] Parsed damages to Pandas DataFrame
# 18:24:26 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:24:26 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-big-m1-mirage.dem
# 18:24:46 [INFO] Wrote demo parse output to vitality-vs-big-m1-mirage.json
# 18:24:46 [INFO] Reading in JSON from vitality-vs-big-m1-mirage.json
# 18:24:47 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:24:47 [INFO] Successfully parsed JSON output
# 18:24:47 [INFO] Successfully returned JSON output
# 18:24:47 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:24:47 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-big-m1-mirage.dem
# 18:25:07 [INFO] Wrote demo parse output to vitality-vs-big-m1-mirage.json
# 18:25:07 [INFO] Reading in JSON from vitality-vs-big-m1-mirage.json
# 18:25:08 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:25:08 [INFO] Successfully parsed JSON output
# 18:25:08 [INFO] Successfully returned JSON output
# 18:25:08 [INFO] Parsed rounds to Pandas DataFrame
# 18:25:08 [INFO] Parsed kills to Pandas DataFrame
# 18:25:08 [INFO] Parsed damages to Pandas DataFrame
# 18:25:08 [INFO] Parsed grenades to Pandas DataFrame
# 18:25:08 [INFO] Parsed flashes to Pandas DataFrame
# 18:25:08 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:25:08 [INFO] Parsed frames to Pandas DataFrame
# 18:25:08 [INFO] Parsed player frames to Pandas DataFrame
# 18:25:08 [INFO] Returned dataframe output
# 18:25:08 [INFO] Parsed kills to Pandas DataFrame
# 18:25:08 [INFO] Parsed grenades to Pandas DataFrame
# 18:25:08 [INFO] Parsed flashes to Pandas DataFrame
# 18:25:08 [INFO] Parsed rounds to Pandas DataFrame
# 18:25:08 [INFO] Parsed damages to Pandas DataFrame
# 18:25:08 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:25:08 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-big-m2-nuke.dem
# 18:25:26 [INFO] Wrote demo parse output to vitality-vs-big-m2-nuke.json
# 18:25:26 [INFO] Reading in JSON from vitality-vs-big-m2-nuke.json
# 18:25:26 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:25:26 [INFO] Successfully parsed JSON output
# 18:25:26 [INFO] Successfully returned JSON output
# 18:25:26 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:25:26 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-big-m2-nuke.dem
# 18:25:43 [INFO] Wrote demo parse output to vitality-vs-big-m2-nuke.json
# 18:25:43 [INFO] Reading in JSON from vitality-vs-big-m2-nuke.json
# 18:25:44 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:25:44 [INFO] Successfully parsed JSON output
# 18:25:44 [INFO] Successfully returned JSON output
# 18:25:44 [INFO] Parsed rounds to Pandas DataFrame
# 18:25:44 [INFO] Parsed kills to Pandas DataFrame
# 18:25:44 [INFO] Parsed damages to Pandas DataFrame
# 18:25:44 [INFO] Parsed grenades to Pandas DataFrame
# 18:25:44 [INFO] Parsed flashes to Pandas DataFrame
# 18:25:44 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:25:44 [INFO] Parsed frames to Pandas DataFrame
# 18:25:44 [INFO] Parsed player frames to Pandas DataFrame
# 18:25:44 [INFO] Returned dataframe output
# 18:25:44 [INFO] Parsed kills to Pandas DataFrame
# 18:25:44 [INFO] Parsed grenades to Pandas DataFrame
# 18:25:44 [INFO] Parsed flashes to Pandas DataFrame
# 18:25:44 [INFO] Parsed rounds to Pandas DataFrame
# 18:25:44 [INFO] Parsed damages to Pandas DataFrame
# 18:25:44 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:25:44 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-furia-m1-vertigo.dem
# 18:25:58 [INFO] Wrote demo parse output to vitality-vs-furia-m1-vertigo.json
# 18:25:58 [INFO] Reading in JSON from vitality-vs-furia-m1-vertigo.json
# 18:25:58 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:25:58 [INFO] Successfully parsed JSON output
# 18:25:58 [INFO] Successfully returned JSON output
# 18:25:58 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:25:58 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-furia-m1-vertigo.dem
# 18:26:12 [INFO] Wrote demo parse output to vitality-vs-furia-m1-vertigo.json
# 18:26:12 [INFO] Reading in JSON from vitality-vs-furia-m1-vertigo.json
# 18:26:12 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:26:12 [INFO] Successfully parsed JSON output
# 18:26:12 [INFO] Successfully returned JSON output
# 18:26:12 [INFO] Parsed rounds to Pandas DataFrame
# 18:26:13 [INFO] Parsed kills to Pandas DataFrame
# 18:26:13 [INFO] Parsed damages to Pandas DataFrame
# 18:26:13 [INFO] Parsed grenades to Pandas DataFrame
# 18:26:13 [INFO] Parsed flashes to Pandas DataFrame
# 18:26:13 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:26:13 [INFO] Parsed frames to Pandas DataFrame
# 18:26:13 [INFO] Parsed player frames to Pandas DataFrame
# 18:26:13 [INFO] Returned dataframe output
# 18:26:13 [INFO] Parsed kills to Pandas DataFrame
# 18:26:13 [INFO] Parsed grenades to Pandas DataFrame
# 18:26:13 [INFO] Parsed flashes to Pandas DataFrame
# 18:26:13 [INFO] Parsed rounds to Pandas DataFrame
# 18:26:13 [INFO] Parsed damages to Pandas DataFrame
# 18:26:13 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:26:13 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-furia-m2-nuke.dem
# 18:26:41 [INFO] Wrote demo parse output to vitality-vs-furia-m2-nuke.json
# 18:26:41 [INFO] Reading in JSON from vitality-vs-furia-m2-nuke.json
# 18:26:41 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:26:41 [INFO] Successfully parsed JSON output
# 18:26:41 [INFO] Successfully returned JSON output
# 18:26:41 [INFO] Running Golang parser from /home/nk095x/cs_demos/csgo/csgo/parser/
# 18:26:41 [INFO] Looking for file at /home/nk095x/cs_demos/csgo/demos/Dreamhack/vitality-vs-furia-m2-nuke.dem
# 18:27:09 [INFO] Wrote demo parse output to vitality-vs-furia-m2-nuke.json
# 18:27:09 [INFO] Reading in JSON from vitality-vs-furia-m2-nuke.json
# 18:27:10 [INFO] JSON data loaded, available in the `json` attribute to parser
# 18:27:10 [INFO] Successfully parsed JSON output
# 18:27:10 [INFO] Successfully returned JSON output
# 18:27:10 [INFO] Parsed rounds to Pandas DataFrame
# 18:27:10 [INFO] Parsed kills to Pandas DataFrame
# 18:27:10 [INFO] Parsed damages to Pandas DataFrame
# 18:27:10 [INFO] Parsed grenades to Pandas DataFrame
# 18:27:10 [INFO] Parsed flashes to Pandas DataFrame
# 18:27:10 [INFO] Parsed bomb_events to Pandas DataFrame
# 18:27:10 [INFO] Parsed frames to Pandas DataFrame
# 18:27:10 [INFO] Parsed player frames to Pandas DataFrame
# 18:27:10 [INFO] Returned dataframe output
# 18:27:10 [INFO] Parsed kills to Pandas DataFrame
# 18:27:10 [INFO] Parsed grenades to Pandas DataFrame
# 18:27:10 [INFO] Parsed flashes to Pandas DataFrame
# 18:27:10 [INFO] Parsed rounds to Pandas DataFrame
# 18:27:10 [INFO] Parsed damages to Pandas DataFrame

# %%
failedDemos = []
gambitMaps, gambitKills, gambitNades, gambitFlashs, gambitRounds, gambitDamages = [], [], [], [], [], []
for x in range(len(kills)):
    if(kills[x].shape[0] > 100):
        gambitMaps.append(maps[x])
        gambitKills.append(kills[x])
        gambitNades.append(nades[x])
        gambitFlashs.append(flashs[x])
        gambitRounds.append(rounds[x])
        gambitDamages.append(damages[x])
    else:
        failedDemos.append(x)

# %%
mirageMaps, mirageKills, mirageNades, mirageFlashs, mirageRounds, mirageDamages = [], [], [], [], [], []
for x in range(len(kills)):
    if(kills[x].MapName.iloc[0] == 'de_mirage'):
        mirageMaps.append(maps[x])
        mirageKills.append(kills[x])
        mirageNades.append(nades[x])
        mirageFlashs.append(flashs[x])
        mirageRounds.append(rounds[x])
        mirageDamages.append(damages[x])

# %%
killData = concat_data(gambitKills)
nadeData = concat_data(gambitNades)
flashData = concat_data(gambitFlashs)
roundData = concat_data(gambitRounds)
damageData = concat_data(gambitDamages)

# %%
mirageKillData = concat_data(mirageKills)
mirageNadeData = concat_data(mirageNades)
mirageFlashData = concat_data(mirageFlashs)
mirageRoundData = concat_data(mirageRounds)
mirageDamageData = concat_data(mirageDamages)

# %%
player_names = list(mirageKillData.AttackerName.value_counts().index)
player_name = {}
for x in player_names:
    player_name[x] = [x]

# %%
for x in range(len(mirageKillData)):
    if  mirageKillData.iloc[x]['AttackerAreaName'] != None:
        print
        mirageKillData.at[x, 'VictimAreaName'] = mappedPlaceNames[mirageKillData.iloc[x]['VictimAreaName']]
        mirageKillData.at[x, 'AttackerAreaName'] = mappedPlaceNames[mirageKillData.iloc[x]['AttackerAreaName']]

for x in range(len(mirageDamageData)):
    if  mirageDamageData.iloc[x]['AttackerAreaName'] != None:
        mirageDamageData.at[x, 'VictimAreaName'] = mappedPlaceNames[mirageDamageData.iloc[x]['VictimAreaName']]
        mirageDamageData.at[x, 'AttackerAreaName'] = mappedPlaceNames[mirageDamageData.iloc[x]['AttackerAreaName']]

# %%
mirageDifferentials = createSidedCSVDF(player_name, mirageDamageData, mirageKillData, mirageRoundData)
# Out:
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:17: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:21: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:22: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:25: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:29: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# /home/nk095x/.local/lib/python3.6/site-packages/ipykernel_launcher.py:30: UserWarning: Boolean Series key will be reindexed to match DataFrame index.

# %%
mirageDifferentials
# Out:
#                  Location  Player  Kills  Deaths  K/D  Damage Dealt  \
# 0               Default A  s1mple      0       0    0             0
# 1               Default A  s1mple      1       1    0            73
# 2                  A Site  s1mple      0       1   -1            15
# 3                  A Site  s1mple      1       3   -2           108
# 4     Mid Close Connector  s1mple      0       1   -1            54
# ...                   ...     ...    ...     ...  ...           ...
# 3229          Deep Jungle    acoR      0       0    0             0
# 3230               Tetris    acoR      0       0    0             0
# 3231               Tetris    acoR      0       0    0             0
# 3232         Ticketbooth     acoR      0       1   -1            72
# 3233         Ticketbooth     acoR      0       0    0             0
#
#       Damage Taken  Damage Differential Side  Total Rounds
# 0               25                  -25   CT            78
# 1               12                   61    T            78
# 2               19                   -4   CT            78
# 3              289                 -181    T            78
# 4              100                  -46   CT            78
# ...            ...                  ...  ...           ...
# 3229             0                    0    T            23
# 3230             0                    0   CT            23
# 3231             0                    0    T            23
# 3232           100                  -28   CT            23
# 3233             0                    0    T            23
#
# [3234 rows x 10 columns]

# %%
mirageDifferentials.to_csv(dreamhack_output_path)

# %%
mirageKillData.to_csv(kills_output_path)

# %%
mirageDamageData.to_csv(damages_output_path)

# %%
mirageRoundData.to_csv(rounds_output_path)
